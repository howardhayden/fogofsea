# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style>\n<section aria-labelledby="fos-cover-title" class="fos-atlas" role="region">\n<div style="display:grid;grid-template-columns:minmax(86px,128px) 1fr;gap:20px;align-items:center;">\n<a aria-label="FOG OF SEA faceted bull and pointed anchor mark. Open public/favicon-day.svg, lines 1 through 80." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/public/favicon-day.svg#L1-L80" rel="noopener" target="_blank" title="public/favicon-day.svg, lines 1 through 80">\n<svg aria-label="FOG OF SEA faceted bull and pointed anchor mark" data-brand-symbol="bull-pointed-anchor" height="120" role="img" style="width:100%;max-width:120px;min-width:0!important;height:auto;display:block;filter:drop-shadow(0 10px 22px rgba(11,21,48,.16));" viewbox="0 0 64 64" width="120" xmlns="http://www.w3.org/2000/svg"><title>FOG OF SEA faceted bull and pointed anchor mark</title><rect fill="#edf4f0" height="64" rx="13" width="64"></rect><g class="brand-bull"><path d="M7 14 25 20 20 29Z" fill="#c8a96b"></path><path d="M57 14 39 20 44 29Z" fill="#c8a96b"></path><path d="m20 21 12-6 12 6-4 25-8 9-8-9Z" fill="#79aca4"></path><path d="m20 21 12 11-8 14Z" fill="#9cc5bb"></path><path d="m44 21-12 11 8 14Z" fill="#5f948d"></path><path d="m24 44 8-5 8 5-4 9h-8Z" fill="#294b4c"></path><circle cx="25" cy="33" fill="#20383a" r="2"></circle><circle cx="39" cy="33" fill="#20383a" r="2"></circle></g><path class="brand-anchor" d="M49 54V21m-2.3 5L49 21l2.3 5M42 31V23m-2.2 5L42 23l2.2 5M56 31V23m-2.2 5L56 23l2.2 5M42 31c0 5 2.4 8 7 8s7-3 7-8" fill="none" stroke="#b18d4e" stroke-linecap="butt" stroke-linejoin="miter" stroke-width="2.6"></path></svg>\n</a>\n<div>\n<h1 id="fos-cover-title" style="font-size:clamp(2.1rem,5vw,4.5rem);line-height:.96;margin:.25rem 0 .75rem;color:#0b1530;font-weight:650;">FOG OF SEA<br/>Systems Atlas</h1>\n<p class="summary" style="font-size:1.06rem;max-width:76ch;">From mission grammar to accepted scenario, environmental coupling, force hosting, mission credit, deterministic command state, fog-of-war disclosure, and local-first persistence.</p>\n</div>\n</div>\n</section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-system-map-summary" aria-labelledby="fos-system-map-title" class="fos-atlas" id="fos-system-map" role="region">\n<header><h2 id="fos-system-map-title">How FOG OF SEA fits together</h2><p class="summary" id="fos-system-map-summary">Play, visualization, command resolution, and persistence remain on the player’s device.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-system-map-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-system-map-stage" aria-pressed="false" data-filter="core" type="button">Core system</button><button aria-controls="fos-system-map-stage" aria-pressed="false" data-filter="delivery" type="button">Delivery</button><button aria-controls="fos-system-map-stage" aria-pressed="false" data-filter="local-data" type="button">Local data</button><button aria-controls="fos-system-map-stage" aria-pressed="false" data-filter="provenance" type="button">Provenance</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-system-map-stage"><svg aria-labelledby="system-context-svg-title system-context-svg-desc" focusable="false" role="img" viewbox="0 0 1020 640">\n<title id="system-context-svg-title">FOG OF SEA, delivery, and local data</title>\n<desc id="system-context-svg-desc">The player uses FOG OF SEA in a browser. Static files arrive from GitHub Pages. Browser save slots and portable text files remain local to the player.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><a aria-label="Player. plans, commands, reviews Player plans, commands, reviews. Open app/page.tsx, lines 1 through 140." class="node-link node" data-node="player" data-tags="core" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/page.tsx, lines 1 through 140"><title>Player. plans, commands, reviews</title><g class="node person"><circle cx="95" cy="208" fill="#fff8e8" r="18" stroke="#4e6178" stroke-width="1.6"></circle><path d="M95 227 V272 M67 244 H123 M95 272 L69 306 M95 272 L121 306" fill="none" stroke="#4e6178" stroke-linecap="round" stroke-width="3"></path><text class="node-title" text-anchor="middle"><tspan x="95" y="333.0">Player</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="95" y="354.0">plans, commands, reviews</tspan></text></g></a><a aria-label="FOG OF SEA. browser-based maritime strategy system FOG OF SEA browser-based maritime strategy system. Open README.md, lines 1 through 120." class="node-link node" data-node="system" data-tags="core" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/README.md#L1-L120" rel="noopener" role="link" tabindex="0" target="_blank" title="README.md, lines 1 through 120"><title>FOG OF SEA. browser-based maritime strategy system</title><g class="node system"><rect class="node-shape" height="245" rx="16" width="340" x="300" y="135"></rect><text class="node-title" text-anchor="middle"><tspan x="470.0" y="249.5">FOG OF SEA</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="470.0" y="277.5">browser-based maritime strategy system</tspan></text></g></a><a aria-label="GitHub Pages. static delivery GitHub Pages static delivery. Open .github/workflows/main.yml, lines 1 through 120." class="node-link node" data-node="pages" data-tags="delivery" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/.github/workflows/main.yml#L1-L120" rel="noopener" role="link" tabindex="0" target="_blank" title=".github/workflows/main.yml, lines 1 through 120"><title>GitHub Pages. static delivery</title><g class="node external"><rect class="node-shape" height="100" rx="16" width="230" x="740" y="55"></rect><text class="node-title" text-anchor="middle"><tspan x="855.0" y="97.0">GitHub Pages</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="855.0" y="125.0">static delivery</tspan></text></g></a><a aria-label="Source repository. versioned code and documents" class="node-link node" data-node="repo" data-tags="delivery provenance" href="https://github.com/howardhayden/fogofsea/tree/d77bdd63189908d9090c1578e20d6f5ce05814c4" rel="noopener" role="link" tabindex="0" target="_blank"><title>Source repository. versioned code and documents</title><g class="node external"><rect class="node-shape" height="100" rx="16" width="230" x="740" y="200"></rect><text class="node-title" text-anchor="middle"><tspan x="855.0" y="242.0">Source repository</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="855.0" y="270.0">versioned code and documents</tspan></text></g></a><a aria-label="Browser storage. opt-in local save slots Browser storage opt-in local save slots. Open app/browserSaves.ts, lines 1 through 160." class="node-link node" data-node="storage" data-tags="local-data" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/browserSaves.ts#L1-L160" rel="noopener" role="link" tabindex="0" target="_blank" title="app/browserSaves.ts, lines 1 through 160"><title>Browser storage. opt-in local save slots</title><g class="node store"><path class="node-shape" d="M745 364 C745 348 965 348 965 364 V441 C965 457 745 457 745 441 Z"></path><ellipse cx="855.0" cy="364" fill="#eef8f4" rx="110.0" ry="14" stroke="#4e6178" stroke-width="1.6"></ellipse><text class="node-title" text-anchor="middle"><tspan x="855.0" y="397.5">Browser storage</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="855.0" y="422.5">opt-in local save slots</tspan></text></g></a><a aria-label="Portable TXT. import / export artifact Portable TXT import / export artifact. Open app/saveGame.ts, lines 1 through 180." class="node-link node" data-node="txt" data-tags="local-data provenance" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/saveGame.ts#L1-L180" rel="noopener" role="link" tabindex="0" target="_blank" title="app/saveGame.ts, lines 1 through 180"><title>Portable TXT. import / export artifact</title><g class="node external"><rect class="node-shape" height="90" rx="16" width="230" x="740" y="500"></rect><text class="node-title" text-anchor="middle"><tspan x="855.0" y="537.0">Portable TXT</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="855.0" y="565.0">import / export artifact</tspan></text></g></a><g data-edge="" data-tags="core"><path class="edge" d="M145 260 L300 255"></path><text class="edge-label" text-anchor="middle" x="222.5" y="250.5">uses</text></g><g data-edge="" data-tags="delivery"><path class="edge" d="M855 155 L640 185"></path><text class="edge-label" text-anchor="middle" x="747.5" y="163.0">delivers static files</text></g><g data-edge="" data-tags="delivery provenance"><path class="edge" d="M740 250 L640 250"></path><text class="edge-label" text-anchor="middle" x="690.0" y="243.0">builds from source</text></g><g data-edge="" data-tags="local-data"><path class="edge" d="M640 300 L745 400"></path><text class="edge-label" text-anchor="middle" x="692.5" y="343.0">reads / writes</text></g><g data-edge="" data-tags="local-data provenance"><path class="edge" d="M640 330 L740 545"></path><text class="edge-label" text-anchor="middle" x="690.0" y="430.5">imports / exports</text></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="person">Person</span><span class="system">System</span><span class="external">External service or file</span><span class="store">Local data store</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/page.tsx</code>, lines <a aria-label="Open app/page.tsx, lines 1 through 140." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" target="_blank" title="app/page.tsx, lines 1 through 140">1–140</a></li><li><code>.github/workflows/main.yml</code>, lines <a aria-label="Open .github/workflows/main.yml, lines 1 through 120." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/.github/workflows/main.yml#L1-L120" rel="noopener" target="_blank" title=".github/workflows/main.yml, lines 1 through 120">1–120</a></li><li><code>app/browserSaves.ts</code>, lines <a aria-label="Open app/browserSaves.ts, lines 1 through 160." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/browserSaves.ts#L1-L160" rel="noopener" target="_blank" title="app/browserSaves.ts, lines 1 through 160">1–160</a></li><li><code>app/saveGame.ts</code>, lines <a aria-label="Open app/saveGame.ts, lines 1 through 180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/saveGame.ts#L1-L180" rel="noopener" target="_blank" title="app/saveGame.ts, lines 1 through 180">1–180</a></li><li><code>README.md</code>, lines <a aria-label="Open README.md, lines 1 through 120." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/README.md#L1-L120" rel="noopener" target="_blank" title="README.md, lines 1 through 120">1–120</a></li></ul></div><details><summary>Description</summary><p>A player interacts with FOG OF SEA in a browser. GitHub Pages delivers the compiled static artifact from the source repository. The browser application can write opt-in local save slots and can import or export a portable text artifact. No application server participates in play.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-system-map\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-browser-structure-summary" aria-labelledby="fos-browser-structure-title" class="fos-atlas" id="fos-browser-structure" role="region">\n<header><h2 id="fos-browser-structure-title">Inside the browser</h2><p class="summary" id="fos-browser-structure-summary">One authoritative session state connects scenario generation, planning, command, visualization, reference content, and persistence.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-browser-structure-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-browser-structure-stage" aria-pressed="false" data-filter="scenario" type="button">Scenario</button><button aria-controls="fos-browser-structure-stage" aria-pressed="false" data-filter="planning" type="button">Planning</button><button aria-controls="fos-browser-structure-stage" aria-pressed="false" data-filter="command" type="button">Command</button><button aria-controls="fos-browser-structure-stage" aria-pressed="false" data-filter="visual" type="button">Visualization</button><button aria-controls="fos-browser-structure-stage" aria-pressed="false" data-filter="persistence" type="button">Persistence</button><button aria-controls="fos-browser-structure-stage" aria-pressed="false" data-filter="interface" type="button">Interface</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-browser-structure-stage"><svg aria-labelledby="application-structure-svg-title application-structure-svg-desc" focusable="false" role="img" viewbox="0 0 1080 640">\n<title id="application-structure-svg-title">FOG OF SEA browser architecture</title>\n<desc id="application-structure-svg-desc">The interface coordinates scenario generation, planning and readiness, the rigid umpire, tactical visualization, reference content, persistence, and one authoritative session state.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><rect fill="none" height="570" rx="24" stroke="#335c89" stroke-dasharray="10 8" stroke-width="2" width="1030" x="25" y="35"></rect><text class="edge-label" x="45" y="65">Browser application boundary</text><a aria-label="UI shell. phase navigation and controls UI shell phase navigation and controls. Open app/page.tsx, lines 1 through 140." class="node-link node" data-node="ui" data-tags="interface" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/page.tsx, lines 1 through 140"><title>UI shell. phase navigation and controls</title><g class="node system"><rect class="node-shape" height="130" rx="16" width="210" x="55" y="105"></rect><text class="node-title" text-anchor="middle"><tspan x="160.0" y="162.0">UI shell</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="160.0" y="190.0">phase navigation and controls</tspan></text></g></a><a aria-label="Scenario synthesizer. mission + threat + environment Scenario synthesizer mission + threat + environment. Open app/gameModel.ts, lines 2180 through 2400." class="node-link node" data-node="scenario" data-tags="scenario" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L2180-L2400" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 2180 through 2400"><title>Scenario synthesizer. mission + threat + environment</title><g class="node component"><rect class="node-shape" height="120" rx="10" width="220" x="315" y="85"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="308" y="105"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="308" y="133"></rect><text class="node-title" text-anchor="middle"><tspan x="425.0" y="137.0">Scenario synthesizer</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="425.0" y="165.0">mission + threat + environment</tspan></text></g></a><a aria-label="Planning &amp; readiness. credit, adaptation, hard validity Planning &amp; readiness credit, adaptation, hard validity. Open app/forceReadiness.ts, lines 1 through 320." class="node-link node" data-node="planning" data-tags="planning" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" role="link" tabindex="0" target="_blank" title="app/forceReadiness.ts, lines 1 through 320"><title>Planning &amp; readiness. credit, adaptation, hard validity</title><g class="node component"><rect class="node-shape" height="120" rx="10" width="220" x="315" y="265"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="308" y="285"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="308" y="313"></rect><text class="node-title" text-anchor="middle"><tspan x="425.0" y="317.0">Planning &amp; readiness</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="425.0" y="345.0">credit, adaptation, hard validity</tspan></text></g></a><a aria-label="Rigid umpire. six-turn state transition Rigid umpire six-turn state transition. Open app/kriegsspiel.ts, lines 600 through 1100." class="node-link node" data-node="umpire" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L600-L1100" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 600 through 1100"><title>Rigid umpire. six-turn state transition</title><g class="node component"><rect class="node-shape" height="120" rx="10" width="220" x="585" y="265"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="578" y="285"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="578" y="313"></rect><text class="node-title" text-anchor="middle"><tspan x="695.0" y="317.0">Rigid umpire</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="695.0" y="345.0">six-turn state transition</tspan></text></g></a><a aria-label="Tactical visualization. WebGL scene and accessible copy Tactical visualization WebGL scene and accessible copy. Open app/battlefieldScene.ts, lines 1 through 260." class="node-link node" data-node="visual" data-tags="visual" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/battlefieldScene.ts#L1-L260" rel="noopener" role="link" tabindex="0" target="_blank" title="app/battlefieldScene.ts, lines 1 through 260"><title>Tactical visualization. WebGL scene and accessible copy</title><g class="node component"><rect class="node-shape" height="120" rx="10" width="220" x="585" y="85"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="578" y="105"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="578" y="133"></rect><text class="node-title" text-anchor="middle"><tspan x="695.0" y="137.0">Tactical visualization</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="695.0" y="165.0">WebGL scene and accessible copy</tspan></text></g></a><a aria-label="Academy &amp; guides. reference content Academy &amp; guides reference content. Open app/Academy.tsx, lines 1 through 180." class="node-link node" data-node="academy" data-tags="interface" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/Academy.tsx#L1-L180" rel="noopener" role="link" tabindex="0" target="_blank" title="app/Academy.tsx, lines 1 through 180"><title>Academy &amp; guides. reference content</title><g class="node component"><rect class="node-shape" height="120" rx="10" width="170" x="850" y="85"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="843" y="105"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="843" y="133"></rect><text class="node-title" text-anchor="middle"><tspan x="935.0" y="137.0">Academy &amp; guides</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="935.0" y="165.0">reference content</tspan></text></g></a><a aria-label="Persistence. browser saves + TXT Persistence browser saves + TXT. Open app/saveGame.ts, lines 1 through 180." class="node-link node" data-node="persistence" data-tags="persistence" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/saveGame.ts#L1-L180" rel="noopener" role="link" tabindex="0" target="_blank" title="app/saveGame.ts, lines 1 through 180"><title>Persistence. browser saves + TXT</title><g class="node component"><rect class="node-shape" height="120" rx="10" width="170" x="850" y="265"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="843" y="285"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="843" y="313"></rect><text class="node-title" text-anchor="middle"><tspan x="935.0" y="317.0">Persistence</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="935.0" y="345.0">browser saves + TXT</tspan></text></g></a><a aria-label="Session state. single authoritative model Session state single authoritative model. Open app/useGameSession.ts, lines 1 through 260." class="node-link node" data-node="session" data-tags="core" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/useGameSession.ts#L1-L260" rel="noopener" role="link" tabindex="0" target="_blank" title="app/useGameSession.ts, lines 1 through 260"><title>Session state. single authoritative model</title><g class="node store"><path class="node-shape" d="M850 469 C850 453 1020 453 1020 469 V536 C1020 552 850 552 850 536 Z"></path><ellipse cx="935.0" cy="469" fill="#eef8f4" rx="85.0" ry="14" stroke="#4e6178" stroke-width="1.6"></ellipse><text class="node-title" text-anchor="middle"><tspan x="935.0" y="497.5">Session state</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="935.0" y="522.5">single authoritative model</tspan></text></g></a><g data-edge="" data-tags="interface scenario"><path class="edge" d="M265 170 L315 145"></path><text class="edge-label" text-anchor="middle" x="290.0" y="150.5">requests scenario</text></g><g data-edge="" data-tags="interface planning"><path class="edge" d="M265 195 L315 325"></path><text class="edge-label" text-anchor="middle" x="290.0" y="253.0">submits decisions</text></g><g data-edge="" data-tags="planning command"><path class="edge" d="M535 325 L585 325"></path><text class="edge-label" text-anchor="middle" x="560.0" y="318.0">commits readiness</text></g><g data-edge="" data-tags="scenario visual"><path class="edge" d="M535 145 L585 145"></path><text class="edge-label" text-anchor="middle" x="560.0" y="138.0">drives environment</text></g><g data-edge="" data-tags="visual interface"><path class="edge" d="M805 145 L850 145"></path><text class="edge-label" text-anchor="middle" x="827.5" y="138.0">links reference</text></g><g data-edge="" data-tags="command persistence"><path class="edge" d="M805 325 L850 325"></path><text class="edge-label" text-anchor="middle" x="827.5" y="318.0">records history</text></g><g data-edge="" data-tags="core interface"><path class="edge" d="M160 235 V500 H850"></path><text class="edge-label" text-anchor="middle" x="520" y="486">dispatches typed actions</text></g><g data-edge="" data-tags="core persistence command"><path class="edge" d="M850 502 H740 V385"></path><text class="edge-label" text-anchor="middle" x="795" y="438">restores state</text></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="system">Application module</span><span class="external">Reference content</span><span class="store">State or storage</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/page.tsx</code>, lines <a aria-label="Open app/page.tsx, lines 1 through 140." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" target="_blank" title="app/page.tsx, lines 1 through 140">1–140</a></li><li><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1 through 140." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1-L140" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1 through 140">1–140</a></li><li><code>app/forceReadiness.ts</code>, lines <a aria-label="Open app/forceReadiness.ts, lines 1 through 320." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" target="_blank" title="app/forceReadiness.ts, lines 1 through 320">1–320</a></li><li><code>app/kriegsspiel.ts</code>, lines <a aria-label="Open app/kriegsspiel.ts, lines 1 through 380." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L1-L380" rel="noopener" target="_blank" title="app/kriegsspiel.ts, lines 1 through 380">1–380</a></li><li><code>app/battlefieldScene.ts</code>, lines <a aria-label="Open app/battlefieldScene.ts, lines 1 through 260." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/battlefieldScene.ts#L1-L260" rel="noopener" target="_blank" title="app/battlefieldScene.ts, lines 1 through 260">1–260</a></li><li><code>app/browserSaves.ts</code>, lines <a aria-label="Open app/browserSaves.ts, lines 1 through 160." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/browserSaves.ts#L1-L160" rel="noopener" target="_blank" title="app/browserSaves.ts, lines 1 through 160">1–160</a></li><li><code>app/useGameSession.ts</code>, lines <a aria-label="Open app/useGameSession.ts, lines 1 through 260." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/useGameSession.ts#L1-L260" rel="noopener" target="_blank" title="app/useGameSession.ts, lines 1 through 260">1–260</a></li></ul></div><details><summary>Description</summary><p>Within the browser boundary, the UI shell calls the scenario synthesizer and planning modules. Derived readiness is committed to the rigid umpire. The accepted scenario also drives the tactical visualization. Typed session actions coordinate the authoritative state, while persistence stores or restores validated data.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-browser-structure\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-scenario-flow-summary" aria-labelledby="fos-scenario-flow-title" class="fos-atlas" id="fos-scenario-flow" role="region">\n<header><h2 id="fos-scenario-flow-title">From mission grammar to accepted scenario</h2><p class="summary" id="fos-scenario-flow-summary">Mission, environment, force requirements, narrative, actors, and committed uncertainty are validated as one complete scenario.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-scenario-flow-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-scenario-flow-stage" aria-pressed="false" data-filter="mission" type="button">Mission grammar</button><button aria-controls="fos-scenario-flow-stage" aria-pressed="false" data-filter="environment" type="button">Environment</button><button aria-controls="fos-scenario-flow-stage" aria-pressed="false" data-filter="matrix" type="button">Matrix</button><button aria-controls="fos-scenario-flow-stage" aria-pressed="false" data-filter="validation" type="button">Validation</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-scenario-flow-stage"><svg aria-labelledby="uml-activity-svg-title uml-activity-svg-desc" focusable="false" role="img" viewbox="0 0 1100 620">\n<title id="uml-activity-svg-title">Scenario generation and validation</title>\n<desc id="uml-activity-svg-desc">A complete scenario candidate is assembled and validated. Invalid candidates are discarded and regenerated; a deterministic fallback must pass the same validation before presentation.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><circle cx="75" cy="80" fill="#0b1530" r="16"></circle><circle cx="955" cy="560" fill="none" r="18" stroke="#0b1530" stroke-width="3"></circle><circle cx="955" cy="560" fill="#0b1530" r="10"></circle><a aria-label="Select mission family. and compatible threat Select mission family and compatible threat. Open app/gameModel.ts, lines 1120 through 1700." class="node-link node" data-node="mission" data-tags="mission" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1120-L1700" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 1120 through 1700"><title>Select mission family. and compatible threat</title><g class="node process"><rect class="node-shape" height="75" rx="16" width="210" x="130" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="235.0" y="74.5">Select mission family</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="235.0" y="102.5">and compatible threat</tspan></text></g></a><a aria-label="Compose environment. region, climate, time, weather Compose environment region, climate, time, weather. Open app/gameModel.ts, lines 2180 through 2400." class="node-link node" data-node="environment" data-tags="environment" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L2180-L2400" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 2180 through 2400"><title>Compose environment. region, climate, time, weather</title><g class="node process"><rect class="node-shape" height="75" rx="16" width="210" x="390" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="495.0" y="74.5">Compose environment</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="495.0" y="102.5">region, climate, time, weather</tspan></text></g></a><a aria-label="Create scenario matrix. actors, disruptions, committed draws Create scenario matrix actors, disruptions, committed draws. Open app/scenarioMatrix.ts, lines 160 through 420." class="node-link node" data-node="matrix" data-tags="matrix" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L160-L420" rel="noopener" role="link" tabindex="0" target="_blank" title="app/scenarioMatrix.ts, lines 160 through 420"><title>Create scenario matrix. actors, disruptions, committed draws</title><g class="node process"><rect class="node-shape" height="75" rx="16" width="210" x="650" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="755.0" y="74.5">Create scenario matrix</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="755.0" y="102.5">actors, disruptions, committed draws</tspan></text></g></a><a aria-label="Build complete candidate. narrative + force requirements Build complete candidate narrative + force requirements. Open app/gameModel.ts, lines 2180 through 2400." class="node-link node" data-node="candidate" data-tags="mission environment matrix" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L2180-L2400" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 2180 through 2400"><title>Build complete candidate. narrative + force requirements</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="210" x="390" y="190"></rect><text class="node-title" text-anchor="middle"><tspan x="495.0" y="222.0">Build complete candidate</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="495.0" y="250.0">narrative + force requirements</tspan></text></g></a><a aria-label="Validate coexistence. ten coupled facets Validate coexistence ten coupled facets. Open app/gameModel.ts, lines 1900 through 2180." class="node-link node" data-node="validate" data-tags="validation" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 1900 through 2180"><title>Validate coexistence. ten coupled facets</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="210" x="650" y="190"></rect><text class="node-title" text-anchor="middle"><tspan x="755.0" y="222.0">Validate coexistence</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="755.0" y="250.0">ten coupled facets</tspan></text></g></a><a aria-label="Valid? Valid?. Open app/gameModel.ts, lines 1900 through 2180." class="node-link node" data-node="valid" data-tags="validation" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 1900 through 2180"><title>Valid?</title><g class="node process"><polygon class="node-shape" points="955,175.0 1030.0,230 955,285.0 880.0,230"></polygon><text class="node-title" text-anchor="middle"><tspan x="955" y="230.0">Valid?</tspan></text></g></a><a aria-label="Present accepted scenario. atomic state replacement Present accepted scenario atomic state replacement. Open app/page.tsx, lines 1 through 140." class="node-link node" data-node="present" data-tags="validation" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/page.tsx, lines 1 through 140"><title>Present accepted scenario. atomic state replacement</title><g class="node process"><rect class="node-shape" height="75" rx="16" width="230" x="840" y="360"></rect><text class="node-title" text-anchor="middle"><tspan x="955.0" y="389.5">Present accepted scenario</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="955.0" y="417.5">atomic state replacement</tspan></text></g></a><a aria-label="Increment attempt. fresh whole-candidate entropy Increment attempt fresh whole-candidate entropy. Open tests/scenario-variety.test.ts, lines 1 through 180." class="node-link node" data-node="retry" data-tags="validation" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/scenario-variety.test.ts#L1-L180" rel="noopener" role="link" tabindex="0" target="_blank" title="tests/scenario-variety.test.ts, lines 1 through 180"><title>Increment attempt. fresh whole-candidate entropy</title><g class="node process"><rect class="node-shape" height="75" rx="16" width="210" x="540" y="360"></rect><text class="node-title" text-anchor="middle"><tspan x="645.0" y="389.5">Increment attempt</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="645.0" y="417.5">fresh whole-candidate entropy</tspan></text></g></a><a aria-label="Attempts remain? Attempts remain?. Open tests/scenario-variety.test.ts, lines 1 through 180." class="node-link node" data-node="attempts" data-tags="validation" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/scenario-variety.test.ts#L1-L180" rel="noopener" role="link" tabindex="0" target="_blank" title="tests/scenario-variety.test.ts, lines 1 through 180"><title>Attempts remain?</title><g class="node process"><polygon class="node-shape" points="370,345.0 450.0,400 370,455.0 290.0,400"></polygon><text class="node-title" text-anchor="middle"><tspan x="370" y="400.0">Attempts remain?</tspan></text></g></a><a aria-label="Construct fallback. deterministic candidate Construct fallback deterministic candidate. Open app/gameModel.ts, lines 2180 through 2400." class="node-link node" data-node="fallback" data-tags="validation" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L2180-L2400" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 2180 through 2400"><title>Construct fallback. deterministic candidate</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="190" x="120" y="360"></rect><text class="node-title" text-anchor="middle"><tspan x="215.0" y="392.0">Construct fallback</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="215.0" y="420.0">deterministic candidate</tspan></text></g></a><g data-edge="" data-tags="mission"><path class="edge" d="M91 80 L130 82"></path></g><g data-edge="" data-tags="environment"><path class="edge" d="M340 82 L390 82"></path></g><g data-edge="" data-tags="matrix"><path class="edge" d="M600 82 L650 82"></path></g><g data-edge="" data-tags="mission environment matrix"><path class="edge" d="M755 120 V155 H495 V190"></path></g><g data-edge="" data-tags="validation"><path class="edge" d="M600 230 L650 230"></path></g><g data-edge="" data-tags="validation"><path class="edge" d="M860 230 L880 230"></path></g><g data-edge="" data-tags="validation"><path class="edge" d="M955 285 L955 360"></path><text class="edge-label" text-anchor="middle" x="955.0" y="315.5">[yes]</text></g><g data-edge="" data-tags="validation"><path class="edge" d="M880 250 L750 397"></path><text class="edge-label" text-anchor="middle" x="815.0" y="316.5">[no]</text></g><g data-edge="" data-tags="validation"><path class="edge" d="M540 397 L450 400"></path></g><g data-edge="" data-tags="validation"><path class="edge" d="M370 345 V300 H235 V360"></path><text class="edge-label" text-anchor="middle" x="300" y="305">[no]</text></g><g data-edge="" data-tags="validation"><path class="edge" d="M370 455 V500 H495 V270"></path><text class="edge-label" text-anchor="middle" x="430" y="488">[yes] regenerate</text></g><g data-edge="" data-tags="validation"><path class="edge" d="M310 400 H650 V270"></path><text class="edge-label" text-anchor="middle" x="470" y="385">validate fallback</text></g><g data-edge="" data-tags="validation"><path class="edge" d="M955 435 L955 542"></path></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="system">Process step</span><span class="external">Decision</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1120 through 1700." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1120-L1700" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1120 through 1700">1120–1700</a></li><li><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 2180 through 2400." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L2180-L2400" rel="noopener" target="_blank" title="app/gameModel.ts, lines 2180 through 2400">2180–2400</a></li><li><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></li><li><code>app/scenarioMatrix.ts</code>, lines <a aria-label="Open app/scenarioMatrix.ts, lines 160 through 420." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L160-L420" rel="noopener" target="_blank" title="app/scenarioMatrix.ts, lines 160 through 420">160–420</a></li><li><code>tests/scenario-variety.test.ts</code>, lines <a aria-label="Open tests/scenario-variety.test.ts, lines 1 through 180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/scenario-variety.test.ts#L1-L180" rel="noopener" target="_blank" title="tests/scenario-variety.test.ts, lines 1 through 180">1–180</a></li></ul></div><details><summary>Description</summary><p>The activity begins by selecting a mission family and compatible threat, composing the environment, and creating the scenario matrix. The complete candidate is validated across ten coupled facets. Valid candidates are presented. Invalid candidates consume a fresh attempt; when attempts are exhausted, a deterministic fallback is constructed and must pass the same validator before presentation.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-scenario-flow\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-session-flow-summary" aria-labelledby="fos-session-flow-title" class="fos-atlas" id="fos-session-flow" role="region">\n<header><h2 id="fos-session-flow-title">From planning to debrief</h2><p class="summary" id="fos-session-flow-summary">The session moves through persistence choice, strategy, force design, command, debrief, revision, and replay.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-session-flow-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-session-flow-stage" aria-pressed="false" data-filter="entry" type="button">Entry</button><button aria-controls="fos-session-flow-stage" aria-pressed="false" data-filter="planning" type="button">Planning</button><button aria-controls="fos-session-flow-stage" aria-pressed="false" data-filter="command" type="button">Command</button><button aria-controls="fos-session-flow-stage" aria-pressed="false" data-filter="review" type="button">Review</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-session-flow-stage"><svg aria-labelledby="uml-state-svg-title uml-state-svg-desc" focusable="false" role="img" viewbox="0 0 1080 560">\n<title id="uml-state-svg-title">Player session flow</title>\n<desc id="uml-state-svg-desc">The player chooses a persistence mode, completes strategy and force design, resolves up to six command turns, reviews the debrief, and may revise, undo, retry, or begin another scenario.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><circle cx="75" cy="90" fill="#0b1530" r="15"></circle><circle cx="1000" cy="505" fill="none" r="18" stroke="#0b1530" stroke-width="3"></circle><circle cx="1000" cy="505" fill="#0b1530" r="10"></circle><a aria-label="Privacy gate. session-only or browser save Privacy gate session-only or browser save. Open app/page.tsx, lines 1 through 140." class="node-link node" data-node="privacy" data-tags="entry" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/page.tsx, lines 1 through 140"><title>Privacy gate. session-only or browser save</title><g class="node state"><rect class="node-shape" height="90" rx="24" width="200" x="125" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="225.0" y="82.0">Privacy gate</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="225.0" y="110.0">session-only or browser save</tspan></text></g></a><a aria-label="Strategy. warfare + objective + theories + guardrail Strategy warfare + objective + theories + guardrail. Open app/StrategicDecisionFlow.tsx, lines 1 through 280." class="node-link node" data-node="strategy" data-tags="planning" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/StrategicDecisionFlow.tsx#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/StrategicDecisionFlow.tsx, lines 1 through 280"><title>Strategy. warfare + objective + theories + guardrail</title><g class="node state"><rect class="node-shape" height="90" rx="24" width="200" x="390" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="490.0" y="82.0">Strategy</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="490.0" y="110.0">warfare + objective + theories + guardrail</tspan></text></g></a><a aria-label="Force design. platforms + aircraft + packs Force design platforms + aircraft + packs. Open app/page.tsx, lines 1 through 140." class="node-link node" data-node="force" data-tags="planning" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/page.tsx, lines 1 through 140"><title>Force design. platforms + aircraft + packs</title><g class="node state"><rect class="node-shape" height="90" rx="24" width="200" x="655" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="755.0" y="82.0">Force design</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="755.0" y="110.0">platforms + aircraft + packs</tspan></text></g></a><a aria-label="Command active. turn 0..6 orders → deterministic transition Command active turn 0..6 orders → deterministic transition. Open app/commandPhase.ts, lines 1 through 280." class="node-link node" data-node="command" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/commandPhase.ts, lines 1 through 280"><title>Command active. turn 0..6\norders → deterministic transition</title><g class="node state"><rect class="node-shape" height="150" rx="24" width="260" x="655" y="240"></rect><text class="node-title" text-anchor="middle"><tspan x="785.0" y="307.0">Command active</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="785.0" y="326.5">turn 0..6</tspan><tspan x="785.0" y="343.5">orders → deterministic transition</tspan></text></g></a><a aria-label="Debrief. outcome + timeline + history Debrief outcome + timeline + history. Open app/ResultDebrief.tsx, lines 1 through 220." class="node-link node" data-node="debrief" data-tags="review" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/ResultDebrief.tsx#L1-L220" rel="noopener" role="link" tabindex="0" target="_blank" title="app/ResultDebrief.tsx, lines 1 through 220"><title>Debrief. outcome + timeline + history</title><g class="node state"><rect class="node-shape" height="110" rx="24" width="210" x="360" y="250"></rect><text class="node-title" text-anchor="middle"><tspan x="465.0" y="297.0">Debrief</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="465.0" y="325.0">outcome + timeline + history</tspan></text></g></a><a aria-label="Planning reopened. record retained when complete Planning reopened record retained when complete. Open app/commandPhase.ts, lines 1 through 280." class="node-link node" data-node="reopen" data-tags="planning review" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/commandPhase.ts, lines 1 through 280"><title>Planning reopened. record retained when complete</title><g class="node state"><rect class="node-shape" height="100" rx="24" width="205" x="75" y="265"></rect><text class="node-title" text-anchor="middle"><tspan x="177.5" y="307.0">Planning reopened</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="177.5" y="335.0">record retained when complete</tspan></text></g></a><g data-edge="" data-tags="entry"><path class="edge" d="M90 90 L125 90"></path><text class="edge-label" text-anchor="middle" x="107.5" y="83.0">hydrate</text></g><g data-edge="" data-tags="entry planning"><path class="edge" d="M325 90 L390 90"></path><text class="edge-label" text-anchor="middle" x="357.5" y="83.0">choose persistence</text></g><g data-edge="" data-tags="planning"><path class="edge" d="M590 90 L655 90"></path><text class="edge-label" text-anchor="middle" x="622.5" y="83.0">strategic frame complete</text></g><g data-edge="" data-tags="planning command"><path class="edge" d="M785 135 L785 240"></path><text class="edge-label" text-anchor="middle" x="785.0" y="180.5">begin command</text></g><g data-edge="" data-tags="command review"><path class="edge" d="M655 315 L570 305"></path><text class="edge-label" text-anchor="middle" x="612.5" y="303.0">complete / terminal</text></g><g data-edge="" data-tags="command review"><path class="edge" d="M465 360 V430 H785 V390"></path><text class="edge-label" text-anchor="middle" x="630" y="420">retry same scenario</text></g><g data-edge="" data-tags="review planning"><path class="edge" d="M360 305 L280 315"></path><text class="edge-label" text-anchor="middle" x="320.0" y="303.0">return to planning</text></g><g data-edge="" data-tags="planning"><path class="edge" d="M177 265 V180 H490 V135"></path><text class="edge-label" text-anchor="middle" x="330" y="170">revise decisions</text></g><g data-edge="" data-tags="review"><path class="edge" d="M915 315 H1000 V487"></path><text class="edge-label" text-anchor="middle" x="960" y="305">new scenario / end session</text></g><g data-edge="" data-tags="command"><path class="edge" d="M655 300 H600 V245 H655"></path><text class="edge-label" text-anchor="middle" x="622" y="235">undo one exact turn</text></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="system">Session state</span><span class="external">Start or end</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/page.tsx</code>, lines <a aria-label="Open app/page.tsx, lines 1 through 140." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" target="_blank" title="app/page.tsx, lines 1 through 140">1–140</a></li><li><code>app/StrategicDecisionFlow.tsx</code>, lines <a aria-label="Open app/StrategicDecisionFlow.tsx, lines 1 through 280." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/StrategicDecisionFlow.tsx#L1-L280" rel="noopener" target="_blank" title="app/StrategicDecisionFlow.tsx, lines 1 through 280">1–280</a></li><li><code>app/commandPhase.ts</code>, lines <a aria-label="Open app/commandPhase.ts, lines 1 through 280." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" target="_blank" title="app/commandPhase.ts, lines 1 through 280">1–280</a></li><li><code>app/useGameSession.ts</code>, lines <a aria-label="Open app/useGameSession.ts, lines 1 through 260." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/useGameSession.ts#L1-L260" rel="noopener" target="_blank" title="app/useGameSession.ts, lines 1 through 260">1–260</a></li><li><code>app/ResultDebrief.tsx</code>, lines <a aria-label="Open app/ResultDebrief.tsx, lines 1 through 220." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/ResultDebrief.tsx#L1-L220" rel="noopener" target="_blank" title="app/ResultDebrief.tsx, lines 1 through 220">1–220</a></li></ul></div><details><summary>Description</summary><p>After hydration, the player chooses a persistence mode. Strategy unlocks force design. Force design commits readiness and begins command. Command resolves up to six turns and reaches debrief. The player may undo one exact turn, retry the same scenario, return to planning, or create a new scenario. Completed records remain in history when returning to planning.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-session-flow\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-planning-data-summary" aria-labelledby="fos-planning-data-title" class="fos-atlas" id="fos-planning-data" role="region">\n<header><h2 id="fos-planning-data-title">Scenario, catalog, and readiness relationships</h2><p class="summary" id="fos-planning-data-summary">Mission and threat definitions combine with region data to produce a scenario; force selections reference the catalogs; readiness is recalculated from those selections.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-planning-data-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-planning-data-stage" aria-pressed="false" data-filter="scenario" type="button">Scenario grammar</button><button aria-controls="fos-planning-data-stage" aria-pressed="false" data-filter="environment" type="button">Environment</button><button aria-controls="fos-planning-data-stage" aria-pressed="false" data-filter="matrix" type="button">Matrix</button><button aria-controls="fos-planning-data-stage" aria-pressed="false" data-filter="force" type="button">Force data</button><button aria-controls="fos-planning-data-stage" aria-pressed="false" data-filter="command" type="button">Command input</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-planning-data-stage"><svg aria-labelledby="erd-planning-svg-title erd-planning-svg-desc" focusable="false" role="img" viewbox="0 0 1080 720">\n<title id="erd-planning-svg-title">Scenario and planning data relationships</title>\n<desc id="erd-planning-svg-desc">Mission, threat, and region definitions relate to generated scenarios. Each scenario owns a matrix and a force selection. Catalog selections are assigned and projected into derived readiness.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><a aria-label="MissionTemplate: key PK, endState, guardrail, lenses[], minimums MissionTemplate key PK endState guardrail lenses[] minimums. Open app/gameModel.ts, lines 1120 through 1700." class="node-link node" data-node="mission-template" data-tags="scenario" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1120-L1700" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 1120 through 1700"><title>MissionTemplate: key PK, endState, guardrail, lenses[], minimums</title><g class="node entity"><rect class="node-shape" height="148" rx="8" width="190" x="45" y="55"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="190" x="45" y="55"></rect><text class="node-title" text-anchor="middle"><tspan x="140.0" y="79.0">MissionTemplate</tspan></text><text class="node-subtitle" text-anchor="start" x="55" y="105">key PK</text><text class="node-subtitle" text-anchor="start" x="55" y="127">endState</text><text class="node-subtitle" text-anchor="start" x="55" y="149">guardrail</text><text class="node-subtitle" text-anchor="start" x="55" y="171">lenses[]</text><text class="node-subtitle" text-anchor="start" x="55" y="193">minimums</text></g></a><a aria-label="Threat: key PK, required[], recommended[], intelligence[] Threat key PK required[] recommended[] intelligence[]. Open app/gameModel.ts, lines 850 through 1120." class="node-link node" data-node="threat" data-tags="scenario" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L850-L1120" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 850 through 1120"><title>Threat: key PK, required[], recommended[], intelligence[]</title><g class="node entity"><rect class="node-shape" height="126" rx="8" width="170" x="300" y="55"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="170" x="300" y="55"></rect><text class="node-title" text-anchor="middle"><tspan x="385.0" y="79.0">Threat</tspan></text><text class="node-subtitle" text-anchor="start" x="310" y="105">key PK</text><text class="node-subtitle" text-anchor="start" x="310" y="127">required[]</text><text class="node-subtitle" text-anchor="start" x="310" y="149">recommended[]</text><text class="node-subtitle" text-anchor="start" x="310" y="171">intelligence[]</text></g></a><a aria-label="Region: id PK, climate, hemisphere, observer, wind/current Region id PK climate hemisphere observer wind/current. Open app/gameModel.ts, lines 760 through 980." class="node-link node" data-node="region" data-tags="environment" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L760-L980" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 760 through 980"><title>Region: id PK, climate, hemisphere, observer, wind/current</title><g class="node entity"><rect class="node-shape" height="148" rx="8" width="200" x="545" y="45"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="200" x="545" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="645.0" y="69.0">Region</tspan></text><text class="node-subtitle" text-anchor="start" x="555" y="95">id PK</text><text class="node-subtitle" text-anchor="start" x="555" y="117">climate</text><text class="node-subtitle" text-anchor="start" x="555" y="139">hemisphere</text><text class="node-subtitle" text-anchor="start" x="555" y="161">observer</text><text class="node-subtitle" text-anchor="start" x="555" y="183">wind/current</text></g></a><a aria-label="Scenario: id PK, mission + threat, environment fields, required/recommended, political frame Scenario id PK mission + threat environment fields required/recommended political frame. Open app/gameModel.ts, lines 1 through 140." class="node-link node" data-node="scenario" data-tags="scenario environment" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 1 through 140"><title>Scenario: id PK, mission + threat, environment fields, required/recommended, political frame</title><g class="node entity"><rect class="node-shape" height="148" rx="8" width="250" x="340" y="265"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="250" x="340" y="265"></rect><text class="node-title" text-anchor="middle"><tspan x="465.0" y="289.0">Scenario</tspan></text><text class="node-subtitle" text-anchor="start" x="350" y="315">id PK</text><text class="node-subtitle" text-anchor="start" x="350" y="337">mission + threat</text><text class="node-subtitle" text-anchor="start" x="350" y="359">environment fields</text><text class="node-subtitle" text-anchor="start" x="350" y="381">required/recommended</text><text class="node-subtitle" text-anchor="start" x="350" y="403">political frame</text></g></a><a aria-label="ScenarioMatrix: seed PK/FK, forceScale, coordination, disruptions[], draws[6] ScenarioMatrix seed PK/FK forceScale coordination disruptions[] draws[6]. Open app/scenarioMatrix.ts, lines 1 through 140." class="node-link node" data-node="matrix" data-tags="matrix" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/scenarioMatrix.ts, lines 1 through 140"><title>ScenarioMatrix: seed PK/FK, forceScale, coordination, disruptions[], draws[6]</title><g class="node entity"><rect class="node-shape" height="148" rx="8" width="220" x="680" y="250"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="220" x="680" y="250"></rect><text class="node-title" text-anchor="middle"><tspan x="790.0" y="274.0">ScenarioMatrix</tspan></text><text class="node-subtitle" text-anchor="start" x="690" y="300">seed PK/FK</text><text class="node-subtitle" text-anchor="start" x="690" y="322">forceScale</text><text class="node-subtitle" text-anchor="start" x="690" y="344">coordination</text><text class="node-subtitle" text-anchor="start" x="690" y="366">disruptions[]</text><text class="node-subtitle" text-anchor="start" x="690" y="388">draws[6]</text></g></a><a aria-label="ForceSelection: scenarioId FK, platformCounts, aircraftCounts, armamentCounts, selectedWarfare ForceSelection scenarioId FK platformCounts aircraftCounts armamentCounts selectedWarfare. Open app/forceReadiness.ts, lines 1 through 320." class="node-link node" data-node="selection" data-tags="force" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" role="link" tabindex="0" target="_blank" title="app/forceReadiness.ts, lines 1 through 320"><title>ForceSelection: scenarioId FK, platformCounts, aircraftCounts, armamentCounts, selectedWarfare</title><g class="node entity"><rect class="node-shape" height="148" rx="8" width="220" x="65" y="300"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="220" x="65" y="300"></rect><text class="node-title" text-anchor="middle"><tspan x="175.0" y="324.0">ForceSelection</tspan></text><text class="node-subtitle" text-anchor="start" x="75" y="350">scenarioId FK</text><text class="node-subtitle" text-anchor="start" x="75" y="372">platformCounts</text><text class="node-subtitle" text-anchor="start" x="75" y="394">aircraftCounts</text><text class="node-subtitle" text-anchor="start" x="75" y="416">armamentCounts</text><text class="node-subtitle" text-anchor="start" x="75" y="438">selectedWarfare</text></g></a><a aria-label="Platform: id PK, aviationKinds[], capacity, armamentSlots Platform id PK aviationKinds[] capacity armamentSlots. Open app/catalog.ts, lines 1 through 340." class="node-link node" data-node="platform" data-tags="force" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" role="link" tabindex="0" target="_blank" title="app/catalog.ts, lines 1 through 340"><title>Platform: id PK, aviationKinds[], capacity, armamentSlots</title><g class="node entity"><rect class="node-shape" height="126" rx="8" width="180" x="60" y="520"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="180" x="60" y="520"></rect><text class="node-title" text-anchor="middle"><tspan x="150.0" y="544.0">Platform</tspan></text><text class="node-subtitle" text-anchor="start" x="70" y="570">id PK</text><text class="node-subtitle" text-anchor="start" x="70" y="592">aviationKinds[]</text><text class="node-subtitle" text-anchor="start" x="70" y="614">capacity</text><text class="node-subtitle" text-anchor="start" x="70" y="636">armamentSlots</text></g></a><a aria-label="Aircraft: id PK, kind, armamentSlots, tracking Aircraft id PK kind armamentSlots tracking. Open app/catalog.ts, lines 1 through 340." class="node-link node" data-node="aircraft" data-tags="force" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" role="link" tabindex="0" target="_blank" title="app/catalog.ts, lines 1 through 340"><title>Aircraft: id PK, kind, armamentSlots, tracking</title><g class="node entity"><rect class="node-shape" height="126" rx="8" width="180" x="285" y="520"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="180" x="285" y="520"></rect><text class="node-title" text-anchor="middle"><tspan x="375.0" y="544.0">Aircraft</tspan></text><text class="node-subtitle" text-anchor="start" x="295" y="570">id PK</text><text class="node-subtitle" text-anchor="start" x="295" y="592">kind</text><text class="node-subtitle" text-anchor="start" x="295" y="614">armamentSlots</text><text class="node-subtitle" text-anchor="start" x="295" y="636">tracking</text></g></a><a aria-label="Armament: id PK, hostIds[], warfare[], reach Armament id PK hostIds[] warfare[] reach. Open app/gameModel.ts, lines 1 through 140." class="node-link node" data-node="armament" data-tags="force" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 1 through 140"><title>Armament: id PK, hostIds[], warfare[], reach</title><g class="node entity"><rect class="node-shape" height="126" rx="8" width="180" x="510" y="520"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="180" x="510" y="520"></rect><text class="node-title" text-anchor="middle"><tspan x="600.0" y="544.0">Armament</tspan></text><text class="node-subtitle" text-anchor="start" x="520" y="570">id PK</text><text class="node-subtitle" text-anchor="start" x="520" y="592">hostIds[]</text><text class="node-subtitle" text-anchor="start" x="520" y="614">warfare[]</text><text class="node-subtitle" text-anchor="start" x="520" y="636">reach</text></g></a><a aria-label="RigidReadiness: scenarioId FK, missionReady, coverage, reach, trackCapacity, forceManifest RigidReadiness scenarioId FK missionReady coverage reach trackCapacity forceManifest. Open app/forceReadiness.ts, lines 1 through 320." class="node-link node" data-node="readiness" data-tags="force command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" role="link" tabindex="0" target="_blank" title="app/forceReadiness.ts, lines 1 through 320"><title>RigidReadiness: scenarioId FK, missionReady, coverage, reach, trackCapacity, forceManifest</title><g class="node entity"><rect class="node-shape" height="170" rx="8" width="220" x="790" y="500"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="220" x="790" y="500"></rect><text class="node-title" text-anchor="middle"><tspan x="900.0" y="524.0">RigidReadiness</tspan></text><text class="node-subtitle" text-anchor="start" x="800" y="550">scenarioId FK</text><text class="node-subtitle" text-anchor="start" x="800" y="572">missionReady</text><text class="node-subtitle" text-anchor="start" x="800" y="594">coverage</text><text class="node-subtitle" text-anchor="start" x="800" y="616">reach</text><text class="node-subtitle" text-anchor="start" x="800" y="638">trackCapacity</text><text class="node-subtitle" text-anchor="start" x="800" y="660">forceManifest</text></g></a><g data-tags="scenario"><path class="edge" d="M235 115 L340 305" style="marker-end:none"></path><path d="M328 297 L340 305 L328 313 M328 305 L340 305" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="249" y="107">1</text><text class="edge-label" x="306" y="297">0..*</text><text class="edge-label" text-anchor="middle" x="287.5" y="202.0">instantiates</text></g><g data-tags="scenario"><path class="edge" d="M470 115 L420 265" style="marker-end:none"></path><path d="M408 257 L420 265 L408 273 M408 265 L420 265" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="484" y="107">1</text><text class="edge-label" x="386" y="257">0..*</text><text class="edge-label" text-anchor="middle" x="445.0" y="182.0">constrains</text></g><g data-tags="environment"><path class="edge" d="M645 155 L535 265" style="marker-end:none"></path><path d="M523 257 L535 265 L523 273 M523 265 L535 265" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="659" y="147">1</text><text class="edge-label" x="501" y="257">0..*</text><text class="edge-label" text-anchor="middle" x="590.0" y="202.0">locates</text></g><g data-tags="matrix"><path class="edge" d="M590 330 L680 315" style="marker-end:none"></path><path d="M668 307 L680 315 L668 323 M668 315 L680 315" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="604" y="322">1</text><text class="edge-label" x="646" y="307">1</text><text class="edge-label" text-anchor="middle" x="635.0" y="314.5">owns</text></g><g data-tags="force"><path class="edge" d="M285 350 L340 350" style="marker-end:none"></path><path d="M328 342 L340 350 L328 358 M328 350 L340 350" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="299" y="342">1</text><text class="edge-label" x="306" y="342">1</text><text class="edge-label" text-anchor="middle" x="312.5" y="342.0">plans for</text></g><g data-tags="force"><path class="edge" d="M175 440 L150 520" style="marker-end:none"></path><path d="M138 512 L150 520 L138 528 M138 520 L150 520" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="189" y="432">1</text><text class="edge-label" x="116" y="512">0..*</text><text class="edge-label" text-anchor="middle" x="162.5" y="472.0">selects</text></g><g data-tags="force"><path class="edge" d="M210 430 L375 520" style="marker-end:none"></path><path d="M363 512 L375 520 L363 528 M363 520 L375 520" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="224" y="422">1</text><text class="edge-label" x="341" y="512">0..*</text><text class="edge-label" text-anchor="middle" x="292.5" y="467.0">embarks</text></g><g data-tags="force"><path class="edge" d="M245 410 L600 520" style="marker-end:none"></path><path d="M588 512 L600 520 L588 528 M588 520 L600 520" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="259" y="402">1</text><text class="edge-label" x="566" y="512">0..*</text><text class="edge-label" text-anchor="middle" x="422.5" y="457.0">loads</text></g><g data-tags="force command"><path class="edge" d="M285 355 L790 555" style="marker-end:none"></path><path d="M778 547 L790 555 L778 563 M778 555 L790 555" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="299" y="347">1</text><text class="edge-label" x="756" y="547">1</text><text class="edge-label" text-anchor="middle" x="537.5" y="447.0">derives</text></g><g data-tags="matrix command"><path class="edge" d="M900 380 L900 500" style="marker-end:none"></path><path d="M888 492 L900 500 L888 508 M888 500 L900 500" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="914" y="372">1</text><text class="edge-label" x="866" y="492">1</text><text class="edge-label" text-anchor="middle" x="900.0" y="432.0">conditions</text></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="system">Record or definition</span><span class="store">Derived record</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1 through 140." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1-L140" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1 through 140">1–140</a></li><li><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1120 through 1700." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1120-L1700" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1120 through 1700">1120–1700</a></li><li><code>app/catalog.ts</code>, lines <a aria-label="Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">1–340</a></li><li><code>app/scenarioMatrix.ts</code>, lines <a aria-label="Open app/scenarioMatrix.ts, lines 1 through 140." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L1-L140" rel="noopener" target="_blank" title="app/scenarioMatrix.ts, lines 1 through 140">1–140</a></li><li><code>app/forceReadiness.ts</code>, lines <a aria-label="Open app/forceReadiness.ts, lines 1 through 320." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" target="_blank" title="app/forceReadiness.ts, lines 1 through 320">1–320</a></li></ul></div><details><summary>Description</summary><p>A mission template, threat, and region can participate in many generated scenarios. Each accepted scenario owns one scenario matrix. A force selection belongs to one scenario and selects many platforms, aircraft, and armaments through count maps. One derived readiness object is calculated from the scenario and force selection and is passed into command adjudication.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-planning-data\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-command-data-summary" aria-labelledby="fos-command-data-title" class="fos-atlas" id="fos-command-data" role="region">\n<header><h2 id="fos-command-data-title">State, turn reports, outcomes, and saves</h2><p class="summary" id="fos-command-data-summary">Each resolved turn appends orders, deltas, matrix results, and notes to the command state; completed runs become decision records and portable saves.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-command-data-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-command-data-stage" aria-pressed="false" data-filter="command" type="button">Command state</button><button aria-controls="fos-command-data-stage" aria-pressed="false" data-filter="matrix" type="button">Matrix data</button><button aria-controls="fos-command-data-stage" aria-pressed="false" data-filter="review" type="button">Review record</button><button aria-controls="fos-command-data-stage" aria-pressed="false" data-filter="persistence" type="button">Persistence</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-command-data-stage"><svg aria-labelledby="erd-command-svg-title erd-command-svg-desc" focusable="false" role="img" viewbox="0 0 1100 760">\n<title id="erd-command-svg-title">Command and save data relationships</title>\n<desc id="erd-command-svg-desc">Readiness and orders drive a rigid game state with zero to six turn reports. Completed states produce outcomes and decision records. Portable saves aggregate current state and history.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><a aria-label="RigidReadiness: missionReady, coverage, forcePoints, reach, tracking, forceManifest RigidReadiness missionReady coverage forcePoints reach tracking forceManifest. Open app/forceReadiness.ts, lines 1 through 320." class="node-link node" data-node="r-ready" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" role="link" tabindex="0" target="_blank" title="app/forceReadiness.ts, lines 1 through 320"><title>RigidReadiness: missionReady, coverage, forcePoints, reach, tracking, forceManifest</title><g class="node entity"><rect class="node-shape" height="170" rx="8" width="205" x="45" y="60"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="205" x="45" y="60"></rect><text class="node-title" text-anchor="middle"><tspan x="147.5" y="84.0">RigidReadiness</tspan></text><text class="node-subtitle" text-anchor="start" x="55" y="110">missionReady</text><text class="node-subtitle" text-anchor="start" x="55" y="132">coverage</text><text class="node-subtitle" text-anchor="start" x="55" y="154">forcePoints</text><text class="node-subtitle" text-anchor="start" x="55" y="176">reach</text><text class="node-subtitle" text-anchor="start" x="55" y="198">tracking</text><text class="node-subtitle" text-anchor="start" x="55" y="220">forceManifest</text></g></a><a aria-label="RigidOrders: formation, sensors, tempo, engagement, doctrines + task RigidOrders formation sensors tempo engagement doctrines + task. Open app/kriegsspiel.ts, lines 1 through 380." class="node-link node" data-node="orders" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L1-L380" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 1 through 380"><title>RigidOrders: formation, sensors, tempo, engagement, doctrines + task</title><g class="node entity"><rect class="node-shape" height="148" rx="8" width="205" x="310" y="60"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="205" x="310" y="60"></rect><text class="node-title" text-anchor="middle"><tspan x="412.5" y="84.0">RigidOrders</tspan></text><text class="node-subtitle" text-anchor="start" x="320" y="110">formation</text><text class="node-subtitle" text-anchor="start" x="320" y="132">sensors</text><text class="node-subtitle" text-anchor="start" x="320" y="154">tempo</text><text class="node-subtitle" text-anchor="start" x="320" y="176">engagement</text><text class="node-subtitle" text-anchor="start" x="320" y="198">doctrines + task</text></g></a><a aria-label="RigidGameState: turn, range/contact, integrity/readiness, supply/escalation, objective/cohesion RigidGameState turn range/contact integrity/readiness supply/escalation objective/cohesion. Open app/kriegsspiel.ts, lines 1 through 380." class="node-link node" data-node="state" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L1-L380" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 1 through 380"><title>RigidGameState: turn, range/contact, integrity/readiness, supply/escalation, objective/cohesion</title><g class="node entity"><rect class="node-shape" height="148" rx="8" width="220" x="575" y="45"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="220" x="575" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="685.0" y="69.0">RigidGameState</tspan></text><text class="node-subtitle" text-anchor="start" x="585" y="95">turn</text><text class="node-subtitle" text-anchor="start" x="585" y="117">range/contact</text><text class="node-subtitle" text-anchor="start" x="585" y="139">integrity/readiness</text><text class="node-subtitle" text-anchor="start" x="585" y="161">supply/escalation</text><text class="node-subtitle" text-anchor="start" x="585" y="183">objective/cohesion</text></g></a><a aria-label="ActivatedMatrix: activeDisruptions, secondaryObjective, adverseBias, committedDraws ActivatedMatrix activeDisruptions secondaryObjective adverseBias committedDraws. Open app/scenarioMatrix.ts, lines 360 through 620." class="node-link node" data-node="activated-matrix" data-tags="matrix command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L360-L620" rel="noopener" role="link" tabindex="0" target="_blank" title="app/scenarioMatrix.ts, lines 360 through 620"><title>ActivatedMatrix: activeDisruptions, secondaryObjective, adverseBias, committedDraws</title><g class="node entity"><rect class="node-shape" height="126" rx="8" width="205" x="850" y="40"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="205" x="850" y="40"></rect><text class="node-title" text-anchor="middle"><tspan x="952.5" y="64.0">ActivatedMatrix</tspan></text><text class="node-subtitle" text-anchor="start" x="860" y="90">activeDisruptions</text><text class="node-subtitle" text-anchor="start" x="860" y="112">secondaryObjective</text><text class="node-subtitle" text-anchor="start" x="860" y="134">adverseBias</text><text class="node-subtitle" text-anchor="start" x="860" y="156">committedDraws</text></g></a><a aria-label="TurnReport: turn FK, orders snapshot, delta, matrixResolution, umpireNotes TurnReport turn FK orders snapshot delta matrixResolution umpireNotes. Open app/kriegsspiel.ts, lines 1 through 380." class="node-link node" data-node="report" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L1-L380" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 1 through 380"><title>TurnReport: turn FK, orders snapshot, delta, matrixResolution, umpireNotes</title><g class="node entity"><rect class="node-shape" height="148" rx="8" width="220" x="575" y="315"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="220" x="575" y="315"></rect><text class="node-title" text-anchor="middle"><tspan x="685.0" y="339.0">TurnReport</tspan></text><text class="node-subtitle" text-anchor="start" x="585" y="365">turn FK</text><text class="node-subtitle" text-anchor="start" x="585" y="387">orders snapshot</text><text class="node-subtitle" text-anchor="start" x="585" y="409">delta</text><text class="node-subtitle" text-anchor="start" x="585" y="431">matrixResolution</text><text class="node-subtitle" text-anchor="start" x="585" y="453">umpireNotes</text></g></a><a aria-label="ResolutionMatrix: components[5], ultimate, committedChance, draw + result ResolutionMatrix components[5] ultimate committedChance draw + result. Open app/scenarioMatrix.ts, lines 360 through 620." class="node-link node" data-node="resolution" data-tags="matrix command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L360-L620" rel="noopener" role="link" tabindex="0" target="_blank" title="app/scenarioMatrix.ts, lines 360 through 620"><title>ResolutionMatrix: components[5], ultimate, committedChance, draw + result</title><g class="node entity"><rect class="node-shape" height="126" rx="8" width="205" x="850" y="310"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="205" x="850" y="310"></rect><text class="node-title" text-anchor="middle"><tspan x="952.5" y="334.0">ResolutionMatrix</tspan></text><text class="node-subtitle" text-anchor="start" x="860" y="360">components[5]</text><text class="node-subtitle" text-anchor="start" x="860" y="382">ultimate</text><text class="node-subtitle" text-anchor="start" x="860" y="404">committedChance</text><text class="node-subtitle" text-anchor="start" x="860" y="426">draw + result</text></g></a><a aria-label="Outcome: title, breakdown, findings, notes Outcome title breakdown findings notes. Open app/kriegsspiel.ts, lines 600 through 1100." class="node-link node" data-node="outcome" data-tags="review" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L600-L1100" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 600 through 1100"><title>Outcome: title, breakdown, findings, notes</title><g class="node entity"><rect class="node-shape" height="126" rx="8" width="205" x="310" y="335"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="205" x="310" y="335"></rect><text class="node-title" text-anchor="middle"><tspan x="412.5" y="359.0">Outcome</tspan></text><text class="node-subtitle" text-anchor="start" x="320" y="385">title</text><text class="node-subtitle" text-anchor="start" x="320" y="407">breakdown</text><text class="node-subtitle" text-anchor="start" x="320" y="429">findings</text><text class="node-subtitle" text-anchor="start" x="320" y="451">notes</text></g></a><a aria-label="DecisionRecord: scenario context, force snapshot, turn reports, outcome DecisionRecord scenario context force snapshot turn reports outcome. Open app/commandPhase.ts, lines 1 through 280." class="node-link node" data-node="record" data-tags="review persistence" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/commandPhase.ts, lines 1 through 280"><title>DecisionRecord: scenario context, force snapshot, turn reports, outcome</title><g class="node entity"><rect class="node-shape" height="126" rx="8" width="205" x="45" y="350"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="205" x="45" y="350"></rect><text class="node-title" text-anchor="middle"><tspan x="147.5" y="374.0">DecisionRecord</tspan></text><text class="node-subtitle" text-anchor="start" x="55" y="400">scenario context</text><text class="node-subtitle" text-anchor="start" x="55" y="422">force snapshot</text><text class="node-subtitle" text-anchor="start" x="55" y="444">turn reports</text><text class="node-subtitle" text-anchor="start" x="55" y="466">outcome</text></g></a><a aria-label="PortableSave: scenario, selections, orders/state, history, preferences PortableSave scenario selections orders/state history preferences. Open app/saveGame.ts, lines 1 through 180." class="node-link node" data-node="portable" data-tags="persistence" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/saveGame.ts#L1-L180" rel="noopener" role="link" tabindex="0" target="_blank" title="app/saveGame.ts, lines 1 through 180"><title>PortableSave: scenario, selections, orders/state, history, preferences</title><g class="node entity"><rect class="node-shape" height="148" rx="8" width="220" x="310" y="565"></rect><rect fill="#dfeff6" height="38" rx="8" stroke="#4e6178" stroke-width="1.6" width="220" x="310" y="565"></rect><text class="node-title" text-anchor="middle"><tspan x="420.0" y="589.0">PortableSave</tspan></text><text class="node-subtitle" text-anchor="start" x="320" y="615">scenario</text><text class="node-subtitle" text-anchor="start" x="320" y="637">selections</text><text class="node-subtitle" text-anchor="start" x="320" y="659">orders/state</text><text class="node-subtitle" text-anchor="start" x="320" y="681">history</text><text class="node-subtitle" text-anchor="start" x="320" y="703">preferences</text></g></a><g data-tags="command"><path class="edge" d="M250 125 L575 115" style="marker-end:none"></path><path d="M563 107 L575 115 L563 123 M563 115 L575 115" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="264" y="117">1</text><text class="edge-label" x="541" y="107">1</text><text class="edge-label" text-anchor="middle" x="412.5" y="112.0">initializes</text></g><g data-tags="command"><path class="edge" d="M515 125 L575 160" style="marker-end:none"></path><path d="M563 152 L575 160 L563 168 M563 160 L575 160" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="529" y="117">1</text><text class="edge-label" x="541" y="152">1</text><text class="edge-label" text-anchor="middle" x="545.0" y="134.5">applies to</text></g><g data-tags="matrix command"><path class="edge" d="M850 120 L795 120" style="marker-end:none"></path><path d="M783 112 L795 120 L783 128 M783 120 L795 120" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="864" y="112">1</text><text class="edge-label" x="761" y="112">1</text><text class="edge-label" text-anchor="middle" x="822.5" y="112.0">activates</text></g><g data-tags="command"><path class="edge" d="M685 235 L685 315" style="marker-end:none"></path><path d="M673 307 L685 315 L673 323 M673 315 L685 315" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="699" y="227">1</text><text class="edge-label" x="651" y="307">0..6</text><text class="edge-label" text-anchor="middle" x="685.0" y="267.0">records</text></g><g data-tags="matrix command"><path class="edge" d="M850 380 L795 380" style="marker-end:none"></path><path d="M783 372 L795 380 L783 388 M783 380 L795 380" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="864" y="372">1</text><text class="edge-label" x="761" y="372">0..1</text><text class="edge-label" text-anchor="middle" x="822.5" y="372.0">attached</text></g><g data-tags="review"><path class="edge" d="M575 400 L515 400" style="marker-end:none"></path><path d="M503 392 L515 400 L503 408 M503 400 L515 400" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="589" y="392">0..6</text><text class="edge-label" x="481" y="392">0..1</text><text class="edge-label" text-anchor="middle" x="545.0" y="392.0">summarizes</text></g><g data-tags="review persistence"><path class="edge" d="M310 400 L250 410" style="marker-end:none"></path><path d="M238 402 L250 410 L238 418 M238 410 L250 410" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="324" y="392">1</text><text class="edge-label" x="216" y="402">1</text><text class="edge-label" text-anchor="middle" x="280.0" y="397.0">captured by</text></g><g data-tags="persistence"><path class="edge" d="M150 460 L310 610" style="marker-end:none"></path><path d="M298 602 L310 610 L298 618 M298 610 L310 610" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="164" y="452">0..*</text><text class="edge-label" x="276" y="602">1</text><text class="edge-label" text-anchor="middle" x="230.0" y="527.0">history in</text></g><g data-tags="persistence"><path class="edge" d="M420 490 L420 565" style="marker-end:none"></path><path d="M408 557 L420 565 L408 573 M408 565 L420 565" fill="none" stroke="#4e6178" stroke-width="1.5"></path><text class="edge-label" x="434" y="482">0..1</text><text class="edge-label" x="386" y="557">1</text><text class="edge-label" text-anchor="middle" x="420.0" y="519.5">current result</text></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="system">Record or definition</span><span class="store">Aggregate or stored record</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/kriegsspiel.ts</code>, lines <a aria-label="Open app/kriegsspiel.ts, lines 1 through 380." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L1-L380" rel="noopener" target="_blank" title="app/kriegsspiel.ts, lines 1 through 380">1–380</a></li><li><code>app/scenarioMatrix.ts</code>, lines <a aria-label="Open app/scenarioMatrix.ts, lines 360 through 620." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L360-L620" rel="noopener" target="_blank" title="app/scenarioMatrix.ts, lines 360 through 620">360–620</a></li><li><code>app/commandPhase.ts</code>, lines <a aria-label="Open app/commandPhase.ts, lines 1 through 280." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" target="_blank" title="app/commandPhase.ts, lines 1 through 280">1–280</a></li><li><code>app/saveGame.ts</code>, lines <a aria-label="Open app/saveGame.ts, lines 1 through 180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/saveGame.ts#L1-L180" rel="noopener" target="_blank" title="app/saveGame.ts, lines 1 through 180">1–180</a></li><li><code>app/browserSaves.ts</code>, lines <a aria-label="Open app/browserSaves.ts, lines 1 through 160." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/browserSaves.ts#L1-L160" rel="noopener" target="_blank" title="app/browserSaves.ts, lines 1 through 160">1–160</a></li></ul></div><details><summary>Description</summary><p>One readiness object and one order set participate in each state transition. A rigid state owns zero to six turn reports. A turn report may carry one resolution matrix. A completed state may produce one outcome, which is copied into one decision record. The portable save stores current scenario and command state plus zero or more historical decision records.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-command-data\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-environment-flow-summary" aria-labelledby="fos-environment-flow-title" class="fos-atlas" id="fos-environment-flow" role="region">\n<header><h2 id="fos-environment-flow-title">Environment, adversary, and disclosure</h2><p class="summary" id="fos-environment-flow-summary">The accepted environment shapes operating methods, adversary pressure, contact disclosure, and tactical presentation while the rigid state remains authoritative.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-environment-flow-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-environment-flow-stage" aria-pressed="false" data-filter="mission" type="button">Mission</button><button aria-controls="fos-environment-flow-stage" aria-pressed="false" data-filter="environment" type="button">Environment</button><button aria-controls="fos-environment-flow-stage" aria-pressed="false" data-filter="matrix" type="button">Adversary matrix</button><button aria-controls="fos-environment-flow-stage" aria-pressed="false" data-filter="force" type="button">Force</button><button aria-controls="fos-environment-flow-stage" aria-pressed="false" data-filter="command" type="button">Command</button><button aria-controls="fos-environment-flow-stage" aria-pressed="false" data-filter="disclosure" type="button">Disclosure</button><button aria-controls="fos-environment-flow-stage" aria-pressed="false" data-filter="visual" type="button">Visualization</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-environment-flow-stage"><svg aria-labelledby="dfd-svg-title dfd-svg-desc" focusable="false" role="img" viewbox="0 0 1180 520">\n<title id="dfd-svg-title">Environment, adversary, and disclosure flow</title>\n<desc id="dfd-svg-desc">Mission and environmental inputs produce an accepted scenario. That scenario informs operational fit, adversary pressure, contact disclosure, tactical rendering, and rigid command state.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><a aria-label="Mission and threat grammar Mission &amp; threat grammar external source. Open app/gameModel.ts, lines 1120 through 1700." class="node-link node" data-node="grammar" data-tags="mission" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1120-L1700" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 1120 through 1700"><title>Mission and threat grammar</title><g class="node external"><rect class="node-shape" height="80" rx="16" width="210" x="45" y="70"></rect><text class="node-title" text-anchor="middle"><tspan x="150.0" y="102.0">Mission &amp; threat grammar</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="150.0" y="130.0">external source</tspan></text></g></a><a aria-label="Region and climate model Region &amp; climate model external source. Open app/gameModel.ts, lines 760 through 980." class="node-link node" data-node="region-model" data-tags="environment" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L760-L980" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 760 through 980"><title>Region and climate model</title><g class="node external"><rect class="node-shape" height="80" rx="16" width="210" x="45" y="220"></rect><text class="node-title" text-anchor="middle"><tspan x="150.0" y="252.0">Region &amp; climate model</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="150.0" y="280.0">external source</tspan></text></g></a><a aria-label="Player force and orders Player force &amp; orders external input. Open app/forceReadiness.ts, lines 1 through 320." class="node-link node" data-node="player-input" data-tags="force command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" role="link" tabindex="0" target="_blank" title="app/forceReadiness.ts, lines 1 through 320"><title>Player force and orders</title><g class="node external"><rect class="node-shape" height="80" rx="16" width="210" x="45" y="370"></rect><text class="node-title" text-anchor="middle"><tspan x="150.0" y="402.0">Player force &amp; orders</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="150.0" y="430.0">external input</tspan></text></g></a><a aria-label="1.0 From mission grammar to accepted scenario. build + validate candidate 1.0 From mission grammar to accepted scenario build + validate candidate. Open app/gameModel.ts, lines 2180 through 2400." class="node-link node" data-node="p1" data-tags="mission environment matrix" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L2180-L2400" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 2180 through 2400"><title>1.0 From mission grammar to accepted scenario. build + validate candidate</title><g class="node process"><rect class="node-shape" height="105" rx="16" width="230" x="340" y="85"></rect><text class="node-title" text-anchor="middle"><tspan x="455.0" y="129.5">1.0 From mission grammar to accepted scenario</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="455.0" y="157.5">build + validate candidate</tspan></text></g></a><a aria-label="Accepted scenario. authoritative environment Accepted scenario authoritative environment. Open app/gameModel.ts, lines 1 through 140." class="node-link node" data-node="d1" data-tags="environment mission" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 1 through 140"><title>Accepted scenario. authoritative environment</title><g class="node store"><path class="node-shape" d="M350 259 C350 243 560 243 560 259 V331 C560 347 350 347 350 331 Z"></path><ellipse cx="455.0" cy="259" fill="#eef8f4" rx="105.0" ry="14" stroke="#4e6178" stroke-width="1.6"></ellipse><text class="node-title" text-anchor="middle"><tspan x="455.0" y="290.0">Accepted scenario</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="455.0" y="315.0">authoritative environment</tspan></text></g></a><a aria-label="Operational frame. method + adaptation Operational frame method + adaptation. Open app/operationalStrategy.ts, lines 1 through 280." class="node-link node" data-node="p2" data-tags="environment force" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/operationalStrategy.ts#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/operationalStrategy.ts, lines 1 through 280"><title>Operational frame. method + adaptation</title><g class="node process"><rect class="node-shape" height="95" rx="16" width="210" x="660" y="60"></rect><text class="node-title" text-anchor="middle"><tspan x="765.0" y="99.5">Operational frame</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="765.0" y="127.5">method + adaptation</tspan></text></g></a><a aria-label="Adversary pressure. matrix + disruptions Adversary pressure matrix + disruptions. Open app/scenarioMatrix.ts, lines 360 through 620." class="node-link node" data-node="p3" data-tags="matrix command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L360-L620" rel="noopener" role="link" tabindex="0" target="_blank" title="app/scenarioMatrix.ts, lines 360 through 620"><title>Adversary pressure. matrix + disruptions</title><g class="node process"><rect class="node-shape" height="95" rx="16" width="210" x="660" y="210"></rect><text class="node-title" text-anchor="middle"><tspan x="765.0" y="249.5">Adversary pressure</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="765.0" y="277.5">matrix + disruptions</tspan></text></g></a><a aria-label="Contact disclosure. credited sensing gate Contact disclosure credited sensing gate. Open app/contactVisualization.ts, lines 1 through 230." class="node-link node" data-node="p4" data-tags="force disclosure" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/contactVisualization.ts#L1-L230" rel="noopener" role="link" tabindex="0" target="_blank" title="app/contactVisualization.ts, lines 1 through 230"><title>Contact disclosure. credited sensing gate</title><g class="node process"><rect class="node-shape" height="95" rx="16" width="210" x="660" y="360"></rect><text class="node-title" text-anchor="middle"><tspan x="765.0" y="399.5">Contact disclosure</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="765.0" y="427.5">credited sensing gate</tspan></text></g></a><a aria-label="Tactical rendering. atmosphere + subjects Tactical rendering atmosphere + subjects. Open app/battlefieldScene.ts, lines 1 through 260." class="node-link node" data-node="p5" data-tags="visual environment" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/battlefieldScene.ts#L1-L260" rel="noopener" role="link" tabindex="0" target="_blank" title="app/battlefieldScene.ts, lines 1 through 260"><title>Tactical rendering. atmosphere + subjects</title><g class="node process"><rect class="node-shape" height="95" rx="16" width="210" x="930" y="125"></rect><text class="node-title" text-anchor="middle"><tspan x="1035.0" y="164.5">Tactical rendering</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="1035.0" y="192.5">atmosphere + subjects</tspan></text></g></a><a aria-label="Rigid state. turn metrics + reports Rigid state turn metrics + reports. Open app/kriegsspiel.ts, lines 1 through 380." class="node-link node" data-node="d2" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L1-L380" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 1 through 380"><title>Rigid state. turn metrics + reports</title><g class="node store"><path class="node-shape" d="M930 344 C930 328 1140 328 1140 344 V416 C1140 432 930 432 930 416 Z"></path><ellipse cx="1035.0" cy="344" fill="#eef8f4" rx="105.0" ry="14" stroke="#4e6178" stroke-width="1.6"></ellipse><text class="node-title" text-anchor="middle"><tspan x="1035.0" y="375.0">Rigid state</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="1035.0" y="400.0">turn metrics + reports</tspan></text></g></a><g data-edge="" data-tags="mission"><path class="edge" d="M255 110 L340 135"></path><text class="edge-label" text-anchor="middle" x="297.5" y="115.5">mission problem</text></g><g data-edge="" data-tags="environment"><path class="edge" d="M255 260 L340 155"></path><text class="edge-label" text-anchor="middle" x="297.5" y="200.5">environmental frame</text></g><g data-edge="" data-tags="mission environment matrix"><path class="edge" d="M455 190 L455 245"></path><text class="edge-label" text-anchor="middle" x="455.0" y="210.5">accepted candidate</text></g><g data-edge="" data-tags="environment"><path class="edge" d="M560 285 L660 110"></path><text class="edge-label" text-anchor="middle" x="610.0" y="190.5">scenario fields</text></g><g data-edge="" data-tags="matrix"><path class="edge" d="M560 300 L660 255"></path><text class="edge-label" text-anchor="middle" x="610.0" y="270.5">matrix commitment</text></g><g data-edge="" data-tags="force command"><path class="edge" d="M255 410 H600 V405 H660"></path><text class="edge-label" text-anchor="middle" x="460" y="392">credited force + orders</text></g><g data-edge="" data-tags="matrix command"><path class="edge" d="M870 255 L930 365"></path><text class="edge-label" text-anchor="middle" x="900.0" y="303.0">pressure and disruptions</text></g><g data-edge="" data-tags="force disclosure"><path class="edge" d="M870 405 L930 380"></path><text class="edge-label" text-anchor="middle" x="900.0" y="355">disclosure flags</text></g><g data-edge="" data-tags="environment visual"><path class="edge" d="M870 110 L930 170"></path><text class="edge-label" text-anchor="middle" x="900.0" y="133.0">environment presentation</text></g><g data-edge="" data-tags="command visual"><path class="edge" d="M1035 330 V260 H1035 V220"></path><text class="edge-label" text-anchor="middle" x="1035" y="268">current state</text></g><g data-edge="" data-tags="command disclosure"><path class="edge" d="M930 380 H900 V405 H870"></path><text class="edge-label" text-anchor="middle" x="900" y="426">contact quality</text></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="external">Input source</span><span class="system">Transformation</span><span class="store">State store</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 2180 through 2400." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L2180-L2400" rel="noopener" target="_blank" title="app/gameModel.ts, lines 2180 through 2400">2180–2400</a></li><li><code>app/operationalStrategy.ts</code>, lines <a aria-label="Open app/operationalStrategy.ts, lines 1 through 280." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/operationalStrategy.ts#L1-L280" rel="noopener" target="_blank" title="app/operationalStrategy.ts, lines 1 through 280">1–280</a></li><li><code>app/scenarioMatrix.ts</code>, lines <a aria-label="Open app/scenarioMatrix.ts, lines 360 through 620." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L360-L620" rel="noopener" target="_blank" title="app/scenarioMatrix.ts, lines 360 through 620">360–620</a></li><li><code>app/contactVisualization.ts</code>, lines <a aria-label="Open app/contactVisualization.ts, lines 1 through 230." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/contactVisualization.ts#L1-L230" rel="noopener" target="_blank" title="app/contactVisualization.ts, lines 1 through 230">1–230</a></li><li><code>app/environmentVisuals.ts</code>, lines <a aria-label="Open app/environmentVisuals.ts, lines 1 through 320." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/environmentVisuals.ts#L1-L320" rel="noopener" target="_blank" title="app/environmentVisuals.ts, lines 1 through 320">1–320</a></li><li><code>app/battlefieldScene.ts</code>, lines <a aria-label="Open app/battlefieldScene.ts, lines 1 through 260." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/battlefieldScene.ts#L1-L260" rel="noopener" target="_blank" title="app/battlefieldScene.ts, lines 1 through 260">1–260</a></li><li><code>app/kriegsspiel.ts</code>, lines <a aria-label="Open app/kriegsspiel.ts, lines 1 through 380." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L1-L380" rel="noopener" target="_blank" title="app/kriegsspiel.ts, lines 1 through 380">1–380</a></li></ul></div><details><summary>Description</summary><p>Mission and threat grammar plus the region and climate model enter scenario synthesis. The accepted scenario is stored as the authoritative environment. Operational strategy derives environment-suited methods. The scenario matrix produces adversary pressure and disruptions. Player force and orders influence contact disclosure and command state. Tactical rendering consumes scenario presentation data and the current state, but the rigid state remains the authoritative record.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-environment-flow\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-force-flow-summary" aria-labelledby="fos-force-flow-title" class="fos-atlas" id="fos-force-flow" role="region">\n<header><h2 id="fos-force-flow-title">From selection to command readiness</h2><p class="summary" id="fos-force-flow-summary">Selection, compatibility, hosting, mission relevance, environmental adaptation, and hard validity remain separate steps.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-force-flow-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-force-flow-stage" aria-pressed="false" data-filter="gate" type="button">Warfare gate</button><button aria-controls="fos-force-flow-stage" aria-pressed="false" data-filter="catalog" type="button">Catalogs</button><button aria-controls="fos-force-flow-stage" aria-pressed="false" data-filter="hosting" type="button">Hosting</button><button aria-controls="fos-force-flow-stage" aria-pressed="false" data-filter="credit" type="button">Mission credit</button><button aria-controls="fos-force-flow-stage" aria-pressed="false" data-filter="adaptation" type="button">Adaptation</button><button aria-controls="fos-force-flow-stage" aria-pressed="false" data-filter="assessment" type="button">Assessment</button><button aria-controls="fos-force-flow-stage" aria-pressed="false" data-filter="command" type="button">Command projection</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-force-flow-stage"><svg aria-labelledby="component-force-svg-title component-force-svg-desc" focusable="false" role="img" viewbox="0 0 1160 670">\n<title id="component-force-svg-title">From selection to command readiness flow</title>\n<desc id="component-force-svg-desc">Warfare selections open relevant catalog choices. Aircraft consume compatible deck capacity, mission packs consume compatible host slots, and only connected relevant capability enters adaptation, planning, and command readiness.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><rect fill="none" height="610" rx="22" stroke="#335c89" stroke-dasharray="9 7" stroke-width="2" width="1110" x="20" y="30"></rect><text class="edge-label" x="40" y="58">force planning</text><a aria-label="Warfare gate. selected area + objective Warfare gate selected area + objective. Open app/planningAssessment.ts, lines 1 through 280." class="node-link node" data-node="gate" data-tags="gate" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/planningAssessment.ts#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/planningAssessment.ts, lines 1 through 280"><title>Warfare gate. selected area + objective</title><g class="node component"><rect class="node-shape" height="100" rx="10" width="205" x="55" y="105"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="48" y="125"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="48" y="153"></rect><text class="node-title" text-anchor="middle"><tspan x="157.5" y="147.0">Warfare gate</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="157.5" y="175.0">selected area + objective</tspan></text></g></a><a aria-label="Catalogs. platforms · aircraft · packs Catalogs platforms · aircraft · packs. Open app/catalog.ts, lines 1 through 340." class="node-link node" data-node="catalog-comp" data-tags="catalog" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" role="link" tabindex="0" target="_blank" title="app/catalog.ts, lines 1 through 340"><title>Catalogs. platforms · aircraft · packs</title><g class="node component"><rect class="node-shape" height="100" rx="10" width="205" x="55" y="285"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="48" y="305"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="48" y="333"></rect><text class="node-title" text-anchor="middle"><tspan x="157.5" y="327.0">Catalogs</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="157.5" y="355.0">platforms · aircraft · packs</tspan></text></g></a><a aria-label="Aviation assignment. deck kind + remaining capacity Aviation assignment deck kind + remaining capacity. Open app/gameModel.ts, lines 520 through 720." class="node-link node" data-node="aviation-fit" data-tags="hosting" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L520-L720" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 520 through 720"><title>Aviation assignment. deck kind + remaining capacity</title><g class="node component"><rect class="node-shape" height="100" rx="10" width="220" x="330" y="105"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="323" y="125"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="323" y="153"></rect><text class="node-title" text-anchor="middle"><tspan x="440.0" y="147.0">Aviation assignment</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="440.0" y="175.0">deck kind + remaining capacity</tspan></text></g></a><a aria-label="Armament assignment. host IDs + slot capacity Armament assignment host IDs + slot capacity. Open app/gameModel.ts, lines 520 through 720." class="node-link node" data-node="armament-fit" data-tags="hosting" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L520-L720" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 520 through 720"><title>Armament assignment. host IDs + slot capacity</title><g class="node component"><rect class="node-shape" height="100" rx="10" width="220" x="330" y="285"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="323" y="305"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="323" y="333"></rect><text class="node-title" text-anchor="middle"><tspan x="440.0" y="327.0">Armament assignment</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="440.0" y="355.0">host IDs + slot capacity</tspan></text></g></a><a aria-label="Mission credit. relevance + connected hosts Mission credit relevance + connected hosts. Open app/gameModel.ts, lines 520 through 720." class="node-link node" data-node="mission-credit" data-tags="credit" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L520-L720" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 520 through 720"><title>Mission credit. relevance + connected hosts</title><g class="node component"><rect class="node-shape" height="100" rx="10" width="220" x="625" y="105"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="618" y="125"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="618" y="153"></rect><text class="node-title" text-anchor="middle"><tspan x="735.0" y="147.0">Mission credit</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="735.0" y="175.0">relevance + connected hosts</tspan></text></g></a><a aria-label="Force adaptation. operating-profile fit Force adaptation operating-profile fit. Open app/forceAdaptation.ts, lines 1 through 260." class="node-link node" data-node="adaptation" data-tags="adaptation" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceAdaptation.ts#L1-L260" rel="noopener" role="link" tabindex="0" target="_blank" title="app/forceAdaptation.ts, lines 1 through 260"><title>Force adaptation. operating-profile fit</title><g class="node component"><rect class="node-shape" height="100" rx="10" width="220" x="625" y="285"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="618" y="305"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="618" y="333"></rect><text class="node-title" text-anchor="middle"><tspan x="735.0" y="327.0">Force adaptation</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="735.0" y="355.0">operating-profile fit</tspan></text></g></a><a aria-label="Planning assessment. coverage + hard validity Planning assessment coverage + hard validity. Open app/planningAssessment.ts, lines 1 through 280." class="node-link node" data-node="assessment" data-tags="assessment" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/planningAssessment.ts#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/planningAssessment.ts, lines 1 through 280"><title>Planning assessment. coverage + hard validity</title><g class="node component"><rect class="node-shape" height="100" rx="10" width="190" x="900" y="105"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="893" y="125"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="893" y="153"></rect><text class="node-title" text-anchor="middle"><tspan x="995.0" y="147.0">Planning assessment</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="995.0" y="175.0">coverage + hard validity</tspan></text></g></a><a aria-label="Rigid readiness. command-ready projection Rigid readiness command-ready projection. Open app/forceReadiness.ts, lines 1 through 320." class="node-link node" data-node="rigid-readiness" data-tags="assessment command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" role="link" tabindex="0" target="_blank" title="app/forceReadiness.ts, lines 1 through 320"><title>Rigid readiness. command-ready projection</title><g class="node component"><rect class="node-shape" height="100" rx="10" width="190" x="900" y="285"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="893" y="305"></rect><rect fill="#fff" height="18" rx="2" stroke="#4e6178" stroke-width="1.4" width="14" x="893" y="333"></rect><text class="node-title" text-anchor="middle"><tspan x="995.0" y="327.0">Rigid readiness</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="995.0" y="355.0">command-ready projection</tspan></text></g></a><g data-edge="" data-tags="gate hosting"><path class="edge" d="M260 155 L330 155"></path><text class="edge-label" text-anchor="middle" x="295.0" y="148.0">enables candidates</text></g><g data-edge="" data-tags="catalog hosting"><path class="edge" d="M260 335 L330 155"></path><text class="edge-label" text-anchor="middle" x="295.0" y="238.0">platform capacity</text></g><g data-edge="" data-tags="catalog hosting"><path class="edge" d="M260 335 L330 335"></path><text class="edge-label" text-anchor="middle" x="295.0" y="328.0">host slots</text></g><g data-edge="" data-tags="hosting credit"><path class="edge" d="M550 155 L625 155"></path><text class="edge-label" text-anchor="middle" x="587.5" y="148.0">supported aircraft</text></g><g data-edge="" data-tags="hosting credit"><path class="edge" d="M550 335 L625 155"></path><text class="edge-label" text-anchor="middle" x="587.5" y="238.0">credited packs</text></g><g data-edge="" data-tags="credit assessment"><path class="edge" d="M845 155 L900 155"></path><text class="edge-label" text-anchor="middle" x="872.5" y="148.0">coverage + points</text></g><g data-edge="" data-tags="adaptation assessment"><path class="edge" d="M845 335 L900 335"></path><text class="edge-label" text-anchor="middle" x="872.5" y="328.0">environment fit</text></g><g data-edge="" data-tags="assessment command"><path class="edge" d="M995 205 L995 285"></path><text class="edge-label" text-anchor="middle" x="995.0" y="238.0">projects</text></g><g data-edge="" data-tags="credit command"><path class="edge" d="M725 205 V245 H995 V285"></path><text class="edge-label" text-anchor="middle" x="850" y="238">credited force manifest</text></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="system">Module</span><span class="external">Connection</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/catalog.ts</code>, lines <a aria-label="Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">1–340</a></li><li><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 520 through 720." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L520-L720" rel="noopener" target="_blank" title="app/gameModel.ts, lines 520 through 720">520–720</a></li><li><code>app/forceAdaptation.ts</code>, lines <a aria-label="Open app/forceAdaptation.ts, lines 1 through 260." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceAdaptation.ts#L1-L260" rel="noopener" target="_blank" title="app/forceAdaptation.ts, lines 1 through 260">1–260</a></li><li><code>app/planningAssessment.ts</code>, lines <a aria-label="Open app/planningAssessment.ts, lines 1 through 280." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/planningAssessment.ts#L1-L280" rel="noopener" target="_blank" title="app/planningAssessment.ts, lines 1 through 280">1–280</a></li><li><code>app/forceReadiness.ts</code>, lines <a aria-label="Open app/forceReadiness.ts, lines 1 through 320." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" target="_blank" title="app/forceReadiness.ts, lines 1 through 320">1–320</a></li></ul></div><details><summary>Description</summary><p>The warfare gate restricts available catalog items. Aviation assignment maps aircraft to compatible deck kinds and remaining capacity. Armament assignment maps mission packs to compatible hosts and slots. Mission credit retains only relevant connected capability. Force adaptation and planning assessment contribute to one rigid-readiness projection used by the command umpire.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-force-flow\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-labelledby="fos-compatibility-title" class="fos-atlas" id="fos-compatibility" role="region"><header><h2 id="fos-compatibility-title">Which aircraft can each platform host?</h2><p class="summary">Aircraft are assigned by launch and recovery kind against shared remaining capacity. A platform cannot host an aircraft kind it does not list.</p></header><div aria-label="Aviation-kind emphasis controls" class="toolbar" role="toolbar"><button aria-controls="compat-table" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="compat-table" aria-pressed="false" data-filter="catapult" type="button">Assisted-launch fixed-wing</button><button aria-controls="compat-table" aria-pressed="false" data-filter="short-deck" type="button">Short-deck fixed-wing</button><button aria-controls="compat-table" aria-pressed="false" data-filter="rotary" type="button">Rotary-wing</button><button aria-controls="compat-table" aria-pressed="false" data-filter="uncrewed-fixed" type="button">Uncrewed fixed-wing</button><button aria-controls="compat-table" aria-pressed="false" data-filter="uncrewed-vertical" type="button">Uncrewed vertical-flight</button><span aria-live="polite" class="sr-only" data-live="">All aviation kinds shown.</span></div><div class="stage"><table id="compat-table"><caption>Aircraft hosting by launch and recovery kind</caption><thead><tr><th scope="col">Selected platform</th><th data-kind-header="catapult" scope="col">Assisted-launch fixed-wing</th><th data-kind-header="short-deck" scope="col">Short-deck fixed-wing</th><th data-kind-header="rotary" scope="col">Rotary-wing</th><th data-kind-header="uncrewed-fixed" scope="col">Uncrewed fixed-wing</th><th data-kind-header="uncrewed-vertical" scope="col">Uncrewed vertical-flight</th></tr></thead><tbody><tr><th scope="row"><a aria-label="Fleet aviation ship. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">Fleet aviation ship</a><br/><small>62 shared air spaces</small></th><td class="yes" data-kind="catapult"><span aria-label="compatible">✓</span></td><td class="yes" data-kind="short-deck"><span aria-label="compatible">✓</span></td><td class="yes" data-kind="rotary"><span aria-label="compatible">✓</span></td><td class="yes" data-kind="uncrewed-fixed"><span aria-label="compatible">✓</span></td><td class="yes" data-kind="uncrewed-vertical"><span aria-label="compatible">✓</span></td></tr><tr><th scope="row"><a aria-label="Short-deck aviation ship. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">Short-deck aviation ship</a><br/><small>44 shared air spaces</small></th><td class="no" data-kind="catapult"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="short-deck"><span aria-label="compatible">✓</span></td><td class="yes" data-kind="rotary"><span aria-label="compatible">✓</span></td><td class="yes" data-kind="uncrewed-fixed"><span aria-label="compatible">✓</span></td><td class="yes" data-kind="uncrewed-vertical"><span aria-label="compatible">✓</span></td></tr><tr><th scope="row"><a aria-label="Expeditionary aviation dock. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">Expeditionary aviation dock</a><br/><small>32 shared air spaces</small></th><td class="no" data-kind="catapult"><span aria-label="not compatible">—</span></td><td class="no" data-kind="short-deck"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="rotary"><span aria-label="compatible">✓</span></td><td class="no" data-kind="uncrewed-fixed"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="uncrewed-vertical"><span aria-label="compatible">✓</span></td></tr><tr><th scope="row"><a aria-label="Low-signature uncrewed aviation ship. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">Low-signature uncrewed aviation ship</a><br/><small>40 shared air spaces</small></th><td class="no" data-kind="catapult"><span aria-label="not compatible">—</span></td><td class="no" data-kind="short-deck"><span aria-label="not compatible">—</span></td><td class="no" data-kind="rotary"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="uncrewed-fixed"><span aria-label="compatible">✓</span></td><td class="yes" data-kind="uncrewed-vertical"><span aria-label="compatible">✓</span></td></tr><tr><th scope="row"><a aria-label="Area-defence destroyer. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">Area-defence destroyer</a><br/><small>4 shared air spaces</small></th><td class="no" data-kind="catapult"><span aria-label="not compatible">—</span></td><td class="no" data-kind="short-deck"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="rotary"><span aria-label="compatible">✓</span></td><td class="no" data-kind="uncrewed-fixed"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="uncrewed-vertical"><span aria-label="compatible">✓</span></td></tr><tr><th scope="row"><a aria-label="Multi-role frigate. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">Multi-role frigate</a><br/><small>5 shared air spaces</small></th><td class="no" data-kind="catapult"><span aria-label="not compatible">—</span></td><td class="no" data-kind="short-deck"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="rotary"><span aria-label="compatible">✓</span></td><td class="no" data-kind="uncrewed-fixed"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="uncrewed-vertical"><span aria-label="compatible">✓</span></td></tr><tr><th scope="row"><a aria-label="Stealth littoral corvette. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">Stealth littoral corvette</a><br/><small>4 shared air spaces</small></th><td class="no" data-kind="catapult"><span aria-label="not compatible">—</span></td><td class="no" data-kind="short-deck"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="rotary"><span aria-label="compatible">✓</span></td><td class="no" data-kind="uncrewed-fixed"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="uncrewed-vertical"><span aria-label="compatible">✓</span></td></tr><tr><th scope="row"><a aria-label="Autonomous mine-support ship. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">Autonomous mine-support ship</a><br/><small>10 shared air spaces</small></th><td class="no" data-kind="catapult"><span aria-label="not compatible">—</span></td><td class="no" data-kind="short-deck"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="rotary"><span aria-label="compatible">✓</span></td><td class="no" data-kind="uncrewed-fixed"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="uncrewed-vertical"><span aria-label="compatible">✓</span></td></tr><tr><th scope="row"><a aria-label="Undersea systems tender. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">Undersea systems tender</a><br/><small>8 shared air spaces</small></th><td class="no" data-kind="catapult"><span aria-label="not compatible">—</span></td><td class="no" data-kind="short-deck"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="rotary"><span aria-label="compatible">✓</span></td><td class="no" data-kind="uncrewed-fixed"><span aria-label="not compatible">—</span></td><td class="yes" data-kind="uncrewed-vertical"><span aria-label="compatible">✓</span></td></tr></tbody></table>\n<div style="display:grid;grid-template-columns:repeat(auto-fit,minmax(210px,1fr));gap:10px;margin-top:14px;">\n<a aria-label="Long-range deck strike kind: assisted-launch fixed-wing. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" style="padding:11px;border:1px solid rgba(78,97,120,.25);border-radius:12px;background:#fff;text-decoration:none;color:#132347;" target="_blank" title="app/catalog.ts, lines 1 through 340"><strong>Long-range deck strike</strong><br/><small>kind: assisted-launch fixed-wing</small></a>\n<a aria-label="Short-takeoff multirole kind: short-deck fixed-wing. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" style="padding:11px;border:1px solid rgba(78,97,120,.25);border-radius:12px;background:#fff;text-decoration:none;color:#132347;" target="_blank" title="app/catalog.ts, lines 1 through 340"><strong>Short-takeoff multirole</strong><br/><small>kind: short-deck fixed-wing</small></a>\n<a aria-label="Maritime mission helicopter kind: rotary-wing. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" style="padding:11px;border:1px solid rgba(78,97,120,.25);border-radius:12px;background:#fff;text-decoration:none;color:#132347;" target="_blank" title="app/catalog.ts, lines 1 through 340"><strong>Maritime mission helicopter</strong><br/><small>kind: rotary-wing</small></a>\n<a aria-label="Uncrewed surveillance rotorcraft kind: uncrewed vertical-flight. Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" style="padding:11px;border:1px solid rgba(78,97,120,.25);border-radius:12px;background:#fff;text-decoration:none;color:#132347;" target="_blank" title="app/catalog.ts, lines 1 through 340"><strong>Uncrewed surveillance rotorcraft</strong><br/><small>kind: uncrewed vertical-flight</small></a>\n</div></div><div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/catalog.ts</code>, lines <a aria-label="Open app/catalog.ts, lines 1 through 340." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/catalog.ts#L1-L340" rel="noopener" target="_blank" title="app/catalog.ts, lines 1 through 340">1–340</a></li><li><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 520 through 720." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L520-L720" rel="noopener" target="_blank" title="app/gameModel.ts, lines 520 through 720">520–720</a></li><li><code>app/forceReadiness.ts</code>, lines <a aria-label="Open app/forceReadiness.ts, lines 1 through 320." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" target="_blank" title="app/forceReadiness.ts, lines 1 through 320">1–320</a></li><li><code>tests/playability-diversity.test.ts</code>, lines <a aria-label="Open tests/playability-diversity.test.ts, lines 350 through 540." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/playability-diversity.test.ts#L350-L540" rel="noopener" target="_blank" title="tests/playability-diversity.test.ts, lines 350 through 540">350–540</a></li></ul></div><details><summary>Description</summary><p>The fleet aviation ship supports every modeled aircraft kind. The short-deck ship supports all except assisted-launch aircraft. The expeditionary dock supports rotary and uncrewed vertical-flight aircraft. The uncrewed aviation ship supports uncrewed fixed-wing and vertical-flight aircraft. Smaller escorts and specialist support ships support rotary and uncrewed vertical-flight aircraft. Capacity is multiplied by the selected platform count and then consumed during assignment.</p></details><script>(function(){const root=document.getElementById(\'fos-compatibility\');if(!root)return;const buttons=[...root.querySelectorAll(\'[data-filter]\')];const table=root.querySelector(\'#compat-table\');const cells=[...table.querySelectorAll(\'[data-kind]\')];const heads=[...table.querySelectorAll(\'[data-kind-header]\')];const live=root.querySelector(\'[data-live]\');function apply(tag,label){cells.forEach(c=>c.classList.toggle(\'dim\',tag!==\'all\'&&c.dataset.kind!==tag));heads.forEach(h=>h.classList.toggle(\'dim\',tag!==\'all\'&&h.dataset.kindHeader!==tag));buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));live.textContent=tag===\'all\'?\'All aviation kinds shown.\':label+\' column emphasized.\';}buttons.forEach(b=>b.addEventListener(\'click\',()=>apply(b.dataset.filter,b.textContent.trim())));})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-turn-sequence-summary" aria-labelledby="fos-turn-sequence-title" class="fos-atlas" id="fos-turn-sequence" role="region">\n<header><h2 id="fos-turn-sequence-title">One command turn</h2><p class="summary" id="fos-turn-sequence-summary">The selected order set, current state, derived readiness, and committed scenario matrix produce one deterministic state transition.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-turn-sequence-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-turn-sequence-stage" aria-pressed="false" data-filter="interface" type="button">Interface</button><button aria-controls="fos-turn-sequence-stage" aria-pressed="false" data-filter="planning" type="button">Readiness</button><button aria-controls="fos-turn-sequence-stage" aria-pressed="false" data-filter="command" type="button">Command</button><button aria-controls="fos-turn-sequence-stage" aria-pressed="false" data-filter="matrix" type="button">Matrix</button><button aria-controls="fos-turn-sequence-stage" aria-pressed="false" data-filter="persistence" type="button">Persistence</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-turn-sequence-stage"><svg aria-labelledby="sequence-svg-title sequence-svg-desc" focusable="false" role="img" viewbox="0 0 1210 735">\n<title id="sequence-svg-title">Command-turn sequence</title>\n<desc id="sequence-svg-desc">The player submits orders. Derived readiness and current state enter command resolution. The scenario matrix returns committed component and ultimate results. The next state and report are stored, and a completed run appends a decision record.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><a aria-label="Player. Player. Open app/page.tsx, lines 1 through 140." class="node-link node" data-node="Player" data-tags="interface" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/page.tsx, lines 1 through 140"><title>Player.</title><g class="node external"><rect class="node-shape" height="55" rx="8" width="120" x="30" y="30"></rect><text class="node-title" text-anchor="middle"><tspan x="90.0" y="57.5">Player</tspan></text></g></a><path d="M90 85 V690" stroke="#9fb8c9" stroke-dasharray="7 6" stroke-width="1.4"></path><a aria-label="UI shell. UI shell. Open app/page.tsx, lines 1 through 140." class="node-link node" data-node="UI shell" data-tags="interface" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/page.tsx, lines 1 through 140"><title>UI shell.</title><g class="node external"><rect class="node-shape" height="55" rx="8" width="120" x="185" y="30"></rect><text class="node-title" text-anchor="middle"><tspan x="245.0" y="57.5">UI shell</tspan></text></g></a><path d="M245 85 V690" stroke="#9fb8c9" stroke-dasharray="7 6" stroke-width="1.4"></path><a aria-label="Readiness. Readiness. Open app/forceReadiness.ts, lines 1 through 320." class="node-link node" data-node="Readiness" data-tags="planning" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" role="link" tabindex="0" target="_blank" title="app/forceReadiness.ts, lines 1 through 320"><title>Readiness.</title><g class="node external"><rect class="node-shape" height="55" rx="8" width="120" x="355" y="30"></rect><text class="node-title" text-anchor="middle"><tspan x="415.0" y="57.5">Readiness</tspan></text></g></a><path d="M415 85 V690" stroke="#9fb8c9" stroke-dasharray="7 6" stroke-width="1.4"></path><a aria-label="Command phase. Command phase. Open app/commandPhase.ts, lines 1 through 280." class="node-link node" data-node="Command phase" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/commandPhase.ts, lines 1 through 280"><title>Command phase.</title><g class="node external"><rect class="node-shape" height="55" rx="8" width="120" x="530" y="30"></rect><text class="node-title" text-anchor="middle"><tspan x="590.0" y="57.5">Command phase</tspan></text></g></a><path d="M590 85 V690" stroke="#9fb8c9" stroke-dasharray="7 6" stroke-width="1.4"></path><a aria-label="Rigid umpire. Rigid umpire. Open app/kriegsspiel.ts, lines 600 through 1100." class="node-link node" data-node="Rigid umpire" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L600-L1100" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 600 through 1100"><title>Rigid umpire.</title><g class="node external"><rect class="node-shape" height="55" rx="8" width="120" x="710" y="30"></rect><text class="node-title" text-anchor="middle"><tspan x="770.0" y="57.5">Rigid umpire</tspan></text></g></a><path d="M770 85 V690" stroke="#9fb8c9" stroke-dasharray="7 6" stroke-width="1.4"></path><a aria-label="Scenario matrix. Scenario matrix. Open app/scenarioMatrix.ts, lines 360 through 620." class="node-link node" data-node="Scenario matrix" data-tags="matrix" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L360-L620" rel="noopener" role="link" tabindex="0" target="_blank" title="app/scenarioMatrix.ts, lines 360 through 620"><title>Scenario matrix.</title><g class="node external"><rect class="node-shape" height="55" rx="8" width="120" x="890" y="30"></rect><text class="node-title" text-anchor="middle"><tspan x="950.0" y="57.5">Scenario matrix</tspan></text></g></a><path d="M950 85 V690" stroke="#9fb8c9" stroke-dasharray="7 6" stroke-width="1.4"></path><a aria-label="Session / save. Session / save. Open app/useGameSession.ts, lines 1 through 260." class="node-link node" data-node="Session / save" data-tags="persistence" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/useGameSession.ts#L1-L260" rel="noopener" role="link" tabindex="0" target="_blank" title="app/useGameSession.ts, lines 1 through 260"><title>Session / save.</title><g class="node external"><rect class="node-shape" height="55" rx="8" width="120" x="1060" y="30"></rect><text class="node-title" text-anchor="middle"><tspan x="1120.0" y="57.5">Session / save</tspan></text></g></a><path d="M1120 85 V690" stroke="#9fb8c9" stroke-dasharray="7 6" stroke-width="1.4"></path><g data-edge="m0" data-tags="interface"><path class="edge" d="M90 125 L245 125"></path><text class="edge-label" text-anchor="middle" x="167.5" y="118.0">1. select order set</text></g><g data-edge="m1" data-tags="interface planning"><path class="edge" d="M245 175 L415 175"></path><text class="edge-label" text-anchor="middle" x="330.0" y="168.0">2. obtain derived readiness</text></g><g data-edge="m2" data-tags="interface command"><path class="edge" d="M245 225 L590 225"></path><text class="edge-label" text-anchor="middle" x="417.5" y="218.0">3. resolveCommandTransition</text></g><g data-edge="m3" data-tags="command"><path class="edge" d="M590 285 L770 285"></path><text class="edge-label" text-anchor="middle" x="680.0" y="278.0">4. resolveRigidTurn</text></g><g data-edge="m4" data-tags="command matrix"><path class="edge" d="M770 345 L950 345"></path><text class="edge-label" text-anchor="middle" x="860.0" y="338.0">5. build matrix input</text></g><g data-edge="m5" data-tags="matrix command"><path class="edge" d="M950 405 L770 405"></path><text class="edge-label" text-anchor="middle" x="860.0" y="398.0">6. return committed resolution</text></g><g data-edge="m6" data-tags="command"><path class="edge" d="M770 465 h55 v30 h-55"></path><text class="edge-label" text-anchor="middle" x="840" y="479">7. update metrics + report</text></g><g data-edge="m7" data-tags="command"><path class="edge" d="M770 525 L590 525"></path><text class="edge-label" text-anchor="middle" x="680.0" y="518.0">8. return next rigid state</text></g><g data-edge="m8" data-tags="command persistence"><path class="edge" d="M590 585 L1120 585"></path><text class="edge-label" text-anchor="middle" x="855.0" y="578.0">9. append record when complete</text></g><g data-edge="m9" data-tags="persistence interface"><path class="edge" d="M1120 645 L245 645"></path><text class="edge-label" text-anchor="middle" x="682.5" y="638.0">10. publish state / debrief</text></g><rect fill="#eaf6fb" height="45" stroke="#335c89" width="46" x="392" y="160"></rect><rect fill="#eef6fb" height="390" stroke="#335c89" width="46" x="567" y="210"></rect><rect fill="#fff8e8" height="280" stroke="#335c89" width="46" x="747" y="270"></rect><rect fill="#f5f3fb" height="100" stroke="#335c89" width="46" x="927" y="330"></rect></svg></div>\n<div aria-label="Legend" class="legend"><span class="external">Participant</span><span class="system">Active processing</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/page.tsx</code>, lines <a aria-label="Open app/page.tsx, lines 1 through 140." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" target="_blank" title="app/page.tsx, lines 1 through 140">1–140</a></li><li><code>app/forceReadiness.ts</code>, lines <a aria-label="Open app/forceReadiness.ts, lines 1 through 320." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" target="_blank" title="app/forceReadiness.ts, lines 1 through 320">1–320</a></li><li><code>app/commandPhase.ts</code>, lines <a aria-label="Open app/commandPhase.ts, lines 1 through 280." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" target="_blank" title="app/commandPhase.ts, lines 1 through 280">1–280</a></li><li><code>app/kriegsspiel.ts</code>, lines <a aria-label="Open app/kriegsspiel.ts, lines 600 through 1100." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L600-L1100" rel="noopener" target="_blank" title="app/kriegsspiel.ts, lines 600 through 1100">600–1100</a></li><li><code>app/scenarioMatrix.ts</code>, lines <a aria-label="Open app/scenarioMatrix.ts, lines 360 through 620." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L360-L620" rel="noopener" target="_blank" title="app/scenarioMatrix.ts, lines 360 through 620">360–620</a></li><li><code>app/useGameSession.ts</code>, lines <a aria-label="Open app/useGameSession.ts, lines 1 through 260." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/useGameSession.ts#L1-L260" rel="noopener" target="_blank" title="app/useGameSession.ts, lines 1 through 260">1–260</a></li><li><code>app/saveGame.ts</code>, lines <a aria-label="Open app/saveGame.ts, lines 1 through 180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/saveGame.ts#L1-L180" rel="noopener" target="_blank" title="app/saveGame.ts, lines 1 through 180">1–180</a></li></ul></div><details><summary>Description</summary><p>The player chooses an order set in the UI. The UI supplies derived readiness to the command-phase transition. The command phase calls the rigid turn resolver, which constructs matrix inputs and requests a committed matrix result. The umpire updates the rigid state and report. The command phase returns the next state, appends a decision record when the run completes, and the session or save layer publishes the new state.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-turn-sequence\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-determinism-summary" aria-labelledby="fos-determinism-title" class="fos-atlas" id="fos-determinism" role="region">\n<header><h2 id="fos-determinism-title">Committed uncertainty and exact Undo</h2><p class="summary" id="fos-determinism-summary">Orders alter modeled chances and state effects, but never resample the committed draw. Undo restores the previous state from the recorded delta.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-determinism-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-determinism-stage" aria-pressed="false" data-filter="commitment" type="button">Commitment</button><button aria-controls="fos-determinism-stage" aria-pressed="false" data-filter="command" type="button">Inputs</button><button aria-controls="fos-determinism-stage" aria-pressed="false" data-filter="resolution" type="button">Resolution</button><button aria-controls="fos-determinism-stage" aria-pressed="false" data-filter="state" type="button">State record</button><button aria-controls="fos-determinism-stage" aria-pressed="false" data-filter="undo" type="button">Undo and replay</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-determinism-stage"><svg aria-labelledby="determinism-svg-title determinism-svg-desc" focusable="false" role="img" viewbox="0 0 1110 620">\n<title id="determinism-svg-title">Committed uncertainty and exact Undo</title>\n<desc id="determinism-svg-desc">A scenario commits its draws before orders. Resolution compares derived chance ranges with those draws, records the resulting delta, and allows exact reversal. Replaying identical state and orders reproduces the same result.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><circle cx="65" cy="85" fill="#0b1530" r="15"></circle><circle cx="1030" cy="565" fill="none" r="18" stroke="#0b1530" stroke-width="3"></circle><circle cx="1030" cy="565" fill="#0b1530" r="10"></circle><a aria-label="Commit scenario draws. six ultimate + component hashes Commit scenario draws six ultimate + component hashes. Open app/scenarioMatrix.ts, lines 360 through 620." class="node-link node" data-node="commit" data-tags="commitment" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L360-L620" rel="noopener" role="link" tabindex="0" target="_blank" title="app/scenarioMatrix.ts, lines 360 through 620"><title>Commit scenario draws. six ultimate + component hashes</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="210" x="115" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="220.0" y="77.0">Commit scenario draws</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="220.0" y="105.0">six ultimate + component hashes</tspan></text></g></a><a aria-label="Receive state + orders. no fresh random sample Receive state + orders no fresh random sample. Open app/commandPhase.ts, lines 1 through 280." class="node-link node" data-node="inputs" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/commandPhase.ts, lines 1 through 280"><title>Receive state + orders. no fresh random sample</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="210" x="385" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="490.0" y="77.0">Receive state + orders</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="490.0" y="105.0">no fresh random sample</tspan></text></g></a><a aria-label="Calculate chance ranges. contact · task · environment · coordination · sustainment Calculate chance ranges contact · task · environment · coordination · sustainment. Open app/kriegsspiel.ts, lines 600 through 1100." class="node-link node" data-node="ranges" data-tags="resolution" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L600-L1100" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 600 through 1100"><title>Calculate chance ranges. contact · task · environment · coordination · sustainment</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="210" x="655" y="45"></rect><text class="node-title" text-anchor="middle"><tspan x="760.0" y="77.0">Calculate chance ranges</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="760.0" y="105.0">contact · task · environment · coordination · sustainment</tspan></text></g></a><a aria-label="Compare committed draws. component + ultimate result Compare committed draws component + ultimate result. Open app/scenarioMatrix.ts, lines 360 through 620." class="node-link node" data-node="compare" data-tags="resolution" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L360-L620" rel="noopener" role="link" tabindex="0" target="_blank" title="app/scenarioMatrix.ts, lines 360 through 620"><title>Compare committed draws. component + ultimate result</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="210" x="655" y="220"></rect><text class="node-title" text-anchor="middle"><tspan x="760.0" y="252.0">Compare committed draws</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="760.0" y="280.0">component + ultimate result</tspan></text></g></a><a aria-label="Apply state delta. range, contact, readiness, integrity, supply, escalation, objectives Apply state delta range, contact, readiness, integrity, supply, escalation, objectives. Open app/kriegsspiel.ts, lines 600 through 1100." class="node-link node" data-node="delta" data-tags="state" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L600-L1100" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 600 through 1100"><title>Apply state delta. range, contact, readiness, integrity, supply, escalation, objectives</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="210" x="385" y="220"></rect><text class="node-title" text-anchor="middle"><tspan x="490.0" y="252.0">Apply state delta</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="490.0" y="280.0">range, contact, readiness, integrity, supply, escalation, objectives</tspan></text></g></a><a aria-label="Append turn report. orders + delta + notes + matrix Append turn report orders + delta + notes + matrix. Open app/kriegsspiel.ts, lines 1 through 380." class="node-link node" data-node="report" data-tags="state" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L1-L380" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 1 through 380"><title>Append turn report. orders + delta + notes + matrix</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="210" x="115" y="220"></rect><text class="node-title" text-anchor="middle"><tspan x="220.0" y="252.0">Append turn report</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="220.0" y="280.0">orders + delta + notes + matrix</tspan></text></g></a><a aria-label="Undo? Undo?. Open app/commandPhase.ts, lines 1 through 280." class="node-link node" data-node="undo" data-tags="undo" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/commandPhase.ts, lines 1 through 280"><title>Undo?</title><g class="node process"><polygon class="node-shape" points="520,370.0 605.0,425 520,480.0 435.0,425"></polygon><text class="node-title" text-anchor="middle"><tspan x="520" y="425.0">Undo?</tspan></text></g></a><a aria-label="Subtract recorded delta. restore exact prior state Subtract recorded delta restore exact prior state. Open app/kriegsspiel.ts, lines 600 through 1100." class="node-link node" data-node="restore" data-tags="undo" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L600-L1100" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 600 through 1100"><title>Subtract recorded delta. restore exact prior state</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="210" x="115" y="385"></rect><text class="node-title" text-anchor="middle"><tspan x="220.0" y="417.0">Subtract recorded delta</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="220.0" y="445.0">restore exact prior state</tspan></text></g></a><a aria-label="Advance / complete. next turn or final outcome Advance / complete next turn or final outcome. Open app/kriegsspiel.ts, lines 600 through 1100." class="node-link node" data-node="advance" data-tags="state" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L600-L1100" rel="noopener" role="link" tabindex="0" target="_blank" title="app/kriegsspiel.ts, lines 600 through 1100"><title>Advance / complete. next turn or final outcome</title><g class="node process"><rect class="node-shape" height="80" rx="16" width="210" x="690" y="385"></rect><text class="node-title" text-anchor="middle"><tspan x="795.0" y="417.0">Advance / complete</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="795.0" y="445.0">next turn or final outcome</tspan></text></g></a><g data-edge="" data-tags="commitment"><path class="edge" d="M80 85 L115 85"></path></g><g data-edge="" data-tags="command"><path class="edge" d="M325 85 L385 85"></path></g><g data-edge="" data-tags="resolution"><path class="edge" d="M595 85 L655 85"></path></g><g data-edge="" data-tags="resolution"><path class="edge" d="M760 125 L760 220"></path></g><g data-edge="" data-tags="resolution state"><path class="edge" d="M655 260 L595 260"></path></g><g data-edge="" data-tags="state"><path class="edge" d="M385 260 L325 260"></path></g><g data-edge="" data-tags="state undo"><path class="edge" d="M220 300 V425 H435"></path><text class="edge-label" text-anchor="middle" x="335" y="414">state available</text></g><g data-edge="" data-tags="undo"><path class="edge" d="M435 425 L325 425"></path><text class="edge-label" text-anchor="middle" x="380.0" y="418.0">[yes]</text></g><g data-edge="" data-tags="state"><path class="edge" d="M605 425 L690 425"></path><text class="edge-label" text-anchor="middle" x="647.5" y="418.0">[no]</text></g><g data-edge="" data-tags="undo command resolution"><path class="edge" d="M115 425 H70 V520 H385 V125"></path><text class="edge-label" text-anchor="middle" x="205" y="510">replay same orders → same result</text></g><g data-edge="" data-tags="state"><path class="edge" d="M900 425 L1030 548"></path></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="system">Process step</span><span class="external">Decision</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/scenarioMatrix.ts</code>, lines <a aria-label="Open app/scenarioMatrix.ts, lines 360 through 620." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/scenarioMatrix.ts#L360-L620" rel="noopener" target="_blank" title="app/scenarioMatrix.ts, lines 360 through 620">360–620</a></li><li><code>app/kriegsspiel.ts</code>, lines <a aria-label="Open app/kriegsspiel.ts, lines 600 through 1100." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/kriegsspiel.ts#L600-L1100" rel="noopener" target="_blank" title="app/kriegsspiel.ts, lines 600 through 1100">600–1100</a></li><li><code>app/commandPhase.ts</code>, lines <a aria-label="Open app/commandPhase.ts, lines 1 through 280." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" target="_blank" title="app/commandPhase.ts, lines 1 through 280">1–280</a></li><li><code>tests/compound-adjudication.test.ts</code>, lines <a aria-label="Open tests/compound-adjudication.test.ts, lines 1 through 230." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/compound-adjudication.test.ts#L1-L230" rel="noopener" target="_blank" title="tests/compound-adjudication.test.ts, lines 1 through 230">1–230</a></li><li><code>tests/kriegsspiel.test.ts</code>, lines <a aria-label="Open tests/kriegsspiel.test.ts, lines 1 through 300." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/kriegsspiel.test.ts#L1-L300" rel="noopener" target="_blank" title="tests/kriegsspiel.test.ts, lines 1 through 300">1–300</a></li></ul></div><details><summary>Description</summary><p>The scenario commits six ultimate draws and deterministic component draws. A turn receives the current state and orders, calculates chance ranges, and compares those ranges with the existing draws. The resulting delta is applied and recorded. Undo subtracts the recorded delta to restore the prior state. Replaying the same state and orders produces the same comparison and result.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-determinism\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-runtime-map-summary" aria-labelledby="fos-runtime-map-title" class="fos-atlas" id="fos-runtime-map" role="region">\n<header><h2 id="fos-runtime-map-title">Where the game runs</h2><p class="summary" id="fos-runtime-map-summary">GitHub Pages delivers static files. Rules, state, browser saves, and exported text remain on the player’s device.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-runtime-map-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-runtime-map-stage" aria-pressed="false" data-filter="delivery" type="button">Delivery</button><button aria-controls="fos-runtime-map-stage" aria-pressed="false" data-filter="provenance" type="button">Provenance</button><button aria-controls="fos-runtime-map-stage" aria-pressed="false" data-filter="runtime" type="button">Browser runtime</button><button aria-controls="fos-runtime-map-stage" aria-pressed="false" data-filter="visual" type="button">Visual runtime</button><button aria-controls="fos-runtime-map-stage" aria-pressed="false" data-filter="persistence" type="button">Persistence</button><button aria-controls="fos-runtime-map-stage" aria-pressed="false" data-filter="boundary" type="button">Trust boundary</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-runtime-map-stage"><svg aria-labelledby="deployment-svg-title deployment-svg-desc" focusable="false" role="img" viewbox="0 0 1130 640">\n<title id="deployment-svg-title">Static delivery and local runtime</title>\n<desc id="deployment-svg-desc">The source produces a static site served by GitHub Pages. The browser runs all game modules locally. Optional browser slots and portable text files are the only persistence channels.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><rect fill="none" height="560" rx="28" stroke="#d9897a" stroke-dasharray="12 8" stroke-width="2.3" width="720" x="360" y="45"></rect><text class="edge-label" x="380" y="75">player device and files</text><a aria-label="GitHub Pages. static HTML, JS, CSS, fonts GitHub Pages static HTML, JS, CSS, fonts. Open .github/workflows/main.yml, lines 1 through 120." class="node-link node" data-node="pages-node" data-tags="delivery" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/.github/workflows/main.yml#L1-L120" rel="noopener" role="link" tabindex="0" target="_blank" title=".github/workflows/main.yml, lines 1 through 120"><title>GitHub Pages. static HTML, JS, CSS, fonts</title><g class="node external"><rect class="node-shape" height="110" rx="16" width="235" x="45" y="70"></rect><text class="node-title" text-anchor="middle"><tspan x="162.5" y="117.0">GitHub Pages</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="162.5" y="145.0">static HTML, JS, CSS, fonts</tspan></text></g></a><a aria-label="Source repository. main branch + release checks" class="node-link node" data-node="repo-node" data-tags="delivery provenance" href="https://github.com/howardhayden/fogofsea/tree/d77bdd63189908d9090c1578e20d6f5ce05814c4" rel="noopener" role="link" tabindex="0" target="_blank"><title>Source repository. main branch + release checks</title><g class="node external"><rect class="node-shape" height="110" rx="16" width="235" x="45" y="245"></rect><text class="node-title" text-anchor="middle"><tspan x="162.5" y="292.0">Source repository</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="162.5" y="320.0">main branch + release checks</tspan></text></g></a><a aria-label="Browser. single-page application runtime Browser single-page application runtime. Open app/page.tsx, lines 1 through 140." class="node-link node" data-node="browser-node" data-tags="runtime" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/page.tsx, lines 1 through 140"><title>Browser. single-page application runtime</title><g class="node system"><rect class="node-shape" height="130" rx="16" width="250" x="400" y="90"></rect><text class="node-title" text-anchor="middle"><tspan x="525.0" y="147.0">Browser</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="525.0" y="175.0">single-page application runtime</tspan></text></g></a><a aria-label="Local runtime. React + Vite + Three.js + Web Audio Local runtime React + Vite + Three.js + Web Audio. Open package.json, lines 1 through 80." class="node-link node" data-node="runtime-node" data-tags="runtime visual" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/package.json#L1-L80" rel="noopener" role="link" tabindex="0" target="_blank" title="package.json, lines 1 through 80"><title>Local runtime. React + Vite + Three.js + Web Audio</title><g class="node system"><rect class="node-shape" height="130" rx="16" width="300" x="720" y="90"></rect><text class="node-title" text-anchor="middle"><tspan x="870.0" y="147.0">Local runtime</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="870.0" y="175.0">React + Vite + Three.js + Web Audio</tspan></text></g></a><a aria-label="localStorage. opt-in named slots localStorage opt-in named slots. Open app/browserSaves.ts, lines 1 through 160." class="node-link node" data-node="localstorage" data-tags="persistence" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/browserSaves.ts#L1-L160" rel="noopener" role="link" tabindex="0" target="_blank" title="app/browserSaves.ts, lines 1 through 160"><title>localStorage. opt-in named slots</title><g class="node store"><path class="node-shape" d="M430 334 C430 318 650 318 650 334 V411 C650 427 430 427 430 411 Z"></path><ellipse cx="540.0" cy="334" fill="#eef8f4" rx="110.0" ry="14" stroke="#4e6178" stroke-width="1.6"></ellipse><text class="node-title" text-anchor="middle"><tspan x="540.0" y="367.5">localStorage</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="540.0" y="392.5">opt-in named slots</tspan></text></g></a><a aria-label="Portable TXT save. human text + machine block Portable TXT save human text + machine block. Open app/saveGame.ts, lines 1 through 180." class="node-link node" data-node="txt-artifact" data-tags="persistence" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/saveGame.ts#L1-L180" rel="noopener" role="link" tabindex="0" target="_blank" title="app/saveGame.ts, lines 1 through 180"><title>Portable TXT save. human text + machine block</title><g class="node external"><rect class="node-shape" height="105" rx="16" width="240" x="760" y="320"></rect><text class="node-title" text-anchor="middle"><tspan x="880.0" y="364.5">Portable TXT save</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="880.0" y="392.5">human text + machine block</tspan></text></g></a><a aria-label="No application server. rules and state stay local No application server rules and state stay local. Open SECURITY.md, lines 1 through 180." class="node-link node" data-node="no-server" data-tags="boundary" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/SECURITY.md#L1-L180" rel="noopener" role="link" tabindex="0" target="_blank" title="SECURITY.md, lines 1 through 180"><title>No application server. rules and state stay local</title><g class="node external"><rect class="node-shape" height="80" rx="16" width="250" x="590" y="485"></rect><text class="node-title" text-anchor="middle"><tspan x="715.0" y="517.0">No application server</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="715.0" y="545.0">rules and state stay local</tspan></text></g></a><g data-edge="" data-tags="delivery"><path class="edge" d="M280 125 L400 145"></path><text class="edge-label" text-anchor="middle" x="340.0" y="128.0">HTTPS static delivery</text></g><g data-edge="" data-tags="delivery provenance"><path class="edge" d="M280 300 L45 125"></path><text class="edge-label" text-anchor="middle" x="162.5" y="205.5">workflow publishes artifact</text></g><g data-edge="" data-tags="runtime"><path class="edge" d="M650 155 L720 155"></path><text class="edge-label" text-anchor="middle" x="685.0" y="148.0">loads runtime modules</text></g><g data-edge="" data-tags="persistence"><path class="edge" d="M525 220 L525 320"></path><text class="edge-label" text-anchor="middle" x="525.0" y="263.0">read / write</text></g><g data-edge="" data-tags="persistence"><path class="edge" d="M650 190 L760 370"></path><text class="edge-label" text-anchor="middle" x="705.0" y="273.0">import / export</text></g><g data-edge="" data-tags="boundary"><path class="edge dashed" d="M715 485 V425 H650"></path><text class="edge-label" text-anchor="middle" x="680" y="448">no network dependency during play</text></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="external">Hosted artifact</span><span class="system">Local runtime</span><span class="store">Local data store</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>.github/workflows/main.yml</code>, lines <a aria-label="Open .github/workflows/main.yml, lines 1 through 120." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/.github/workflows/main.yml#L1-L120" rel="noopener" target="_blank" title=".github/workflows/main.yml, lines 1 through 120">1–120</a></li><li><code>package.json</code>, lines <a aria-label="Open package.json, lines 1 through 80." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/package.json#L1-L80" rel="noopener" target="_blank" title="package.json, lines 1 through 80">1–80</a></li><li><code>app/browserSaves.ts</code>, lines <a aria-label="Open app/browserSaves.ts, lines 1 through 160." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/browserSaves.ts#L1-L160" rel="noopener" target="_blank" title="app/browserSaves.ts, lines 1 through 160">1–160</a></li><li><code>app/saveGame.ts</code>, lines <a aria-label="Open app/saveGame.ts, lines 1 through 180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/saveGame.ts#L1-L180" rel="noopener" target="_blank" title="app/saveGame.ts, lines 1 through 180">1–180</a></li><li><code>app/inputSecurity.ts</code>, lines <a aria-label="Open app/inputSecurity.ts, lines 1 through 240." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/inputSecurity.ts#L1-L240" rel="noopener" target="_blank" title="app/inputSecurity.ts, lines 1 through 240">1–240</a></li><li><code>SECURITY.md</code>, lines <a aria-label="Open SECURITY.md, lines 1 through 180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/SECURITY.md#L1-L180" rel="noopener" target="_blank" title="SECURITY.md, lines 1 through 180">1–180</a></li></ul></div><details><summary>Description</summary><p>The source repository produces a static artifact published by GitHub Pages. The user browser loads the application and executes React, Vite-built JavaScript, Three.js, and Web Audio locally. Optional named save slots use localStorage. Portable TXT files cross the browser boundary only through explicit import or export. No application server holds game state or adjudicates turns.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-runtime-map\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-labelledby="fos-traceability-title" class="fos-atlas" id="fos-traceability" role="region"><header><h2 id="fos-traceability-title">How scenario facets stay coherent</h2><p class="summary">Every accepted scenario aligns identity, region, season, weather, sea conditions, celestial eligibility, mission logic, force requirements, the matrix, and narrative.</p></header><div aria-label="Facet filters" class="toolbar" role="toolbar"><button aria-controls="trace-table" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="trace-table" aria-pressed="false" data-filter="environment" type="button">Environment</button><button aria-controls="trace-table" aria-pressed="false" data-filter="strategy" type="button">Strategy</button><button aria-controls="trace-table" aria-pressed="false" data-filter="force" type="button">Force</button><button aria-controls="trace-table" aria-pressed="false" data-filter="matrix" type="button">Matrix</button><button aria-controls="trace-table" aria-pressed="false" data-filter="narrative" type="button">Narrative</button><button aria-controls="trace-table" aria-pressed="false" data-filter="scenario" type="button">Identity</button><span aria-live="polite" class="sr-only" data-live="">All validation facets shown.</span></div><div class="stage"><table id="trace-table"><caption>Scenario coherence map</caption><thead><tr><th scope="col">Facet</th><th scope="col">What must agree</th><th scope="col">What it affects</th><th scope="col">Source</th></tr></thead><tbody><tr data-facet="scenario"><th scope="row">Identity</th><td>operation grammar, IDs, budget identity</td><td>Scenario identity and replay key</td><td><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></td></tr><tr data-facet="environment"><th scope="row">Region–climate</th><td>region label, climate, observer, hemisphere, sound profile</td><td>environment and celestial model</td><td><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></td></tr><tr data-facet="environment"><th scope="row">Season–date</th><td>regional season vocabulary and fixed date</td><td>weather, wildlife, astronomy</td><td><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></td></tr><tr data-facet="environment"><th scope="row">Weather–cloud–precipitation</th><td>cloud regime, precipitation type, storm coupling</td><td>visibility, scene weather, disruption plausibility</td><td><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></td></tr><tr data-facet="environment"><th scope="row">Sea–wind–current–visibility</th><td>wind/sea coupling, current bounds, wave vector</td><td>wave field, sensor friction, route state</td><td><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></td></tr><tr data-facet="environment"><th scope="row">Aurora–celestial</th><td>observer geometry and environment eligibility</td><td>sky and subsurface optics</td><td><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></td></tr><tr data-facet="strategy"><th scope="row">Mission–geography–objective</th><td>mission/threat pair, political aim, theory problem, region geography</td><td>strategic decisions and task relevance</td><td><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></td></tr><tr data-facet="force"><th scope="row">Forces</th><td>budget, unique required/recommended areas, generated minimums</td><td>catalog availability and readiness</td><td><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></td></tr><tr data-facet="matrix"><th scope="row">Difficulty–matrix</th><td>actor count, canonical matrix, committed draws</td><td>disruptions, secondary objectives, turn matrices</td><td><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></td></tr><tr data-facet="narrative"><th scope="row">Narrative</th><td>substantive and structurally distinct fields</td><td>brief, debrief context, portable record</td><td><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1900 through 2180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1900-L2180" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1900 through 2180">1900–2180</a></td></tr></tbody></table></div><div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>tests/scenario-variety.test.ts</code>, lines <a aria-label="Open tests/scenario-variety.test.ts, lines 1 through 180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/scenario-variety.test.ts#L1-L180" rel="noopener" target="_blank" title="tests/scenario-variety.test.ts, lines 1 through 180">1–180</a></li><li><code>tests/playability-diversity.test.ts</code>, lines <a aria-label="Open tests/playability-diversity.test.ts, lines 350 through 540." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/playability-diversity.test.ts#L350-L540" rel="noopener" target="_blank" title="tests/playability-diversity.test.ts, lines 350 through 540">350–540</a></li><li><code>tests/compound-adjudication.test.ts</code>, lines <a aria-label="Open tests/compound-adjudication.test.ts, lines 1 through 230." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/compound-adjudication.test.ts#L1-L230" rel="noopener" target="_blank" title="tests/compound-adjudication.test.ts, lines 1 through 230">1–230</a></li><li><code>tests/kriegsspiel.test.ts</code>, lines <a aria-label="Open tests/kriegsspiel.test.ts, lines 1 through 300." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/kriegsspiel.test.ts#L1-L300" rel="noopener" target="_blank" title="tests/kriegsspiel.test.ts, lines 1 through 300">1–300</a></li><li><code>tests/contact-visualization.test.ts</code>, lines <a aria-label="Open tests/contact-visualization.test.ts, lines 1 through 220." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/contact-visualization.test.ts#L1-L220" rel="noopener" target="_blank" title="tests/contact-visualization.test.ts, lines 1 through 220">1–220</a></li><li><code>ACCESSIBILITY.md</code>, lines <a aria-label="Open ACCESSIBILITY.md, lines 1 through 220." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/ACCESSIBILITY.md#L1-L220" rel="noopener" target="_blank" title="ACCESSIBILITY.md, lines 1 through 220">1–220</a></li></ul></div><details><summary>Description</summary><p>The test suite mutates individual facets, checks that every generated scenario validates, and exercises variety, playability, matrix commitment, contact disclosure, and replay behavior.</p></details><script>(function(){const root=document.getElementById(\'fos-traceability\');if(!root)return;const buttons=[...root.querySelectorAll(\'[data-filter]\')];const rows=[...root.querySelectorAll(\'[data-facet]\')];const live=root.querySelector(\'[data-live]\');function apply(tag,label){rows.forEach(r=>r.classList.toggle(\'hidden-by-filter\',tag!==\'all\'&&r.dataset.facet!==tag));buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));live.textContent=tag===\'all\'?\'All validation facets shown.\':label+\' facets shown.\';}buttons.forEach(b=>b.addEventListener(\'click\',()=>apply(b.dataset.filter,b.textContent.trim())));})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...

# %%
#@title  { display-mode: "form" }
from IPython.display import HTML, display
display(HTML('<style>\n@font-face {\n  font-family: \'Jost\';\n  src: url(\'https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2\') format(\'woff2\');\n  font-weight: 100 900;\n  font-style: normal;\n  font-display: swap;\n}\n.fos-atlas {\n  --night:#0b1530; --navy:#132347; --dawn:#335c89;\n  --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;\n  --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;\n  --ink:#102033; --coral:#d9897a; --teal:#6fbabc;\n  font-family:\'Jost\',Arial,sans-serif; color:var(--ink);\n  background:\n    radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),\n    radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),\n    linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));\n  border:1px solid rgba(78,97,120,.34); border-radius:22px;\n  box-shadow:0 22px 70px rgba(11,21,48,.12), inset 0 1px 0 rgba(255,255,255,.92);\n  padding:clamp(18px,3vw,34px); margin:18px 0 28px; overflow:hidden;\n}\n.fos-atlas * { box-sizing:border-box; }\n.fos-atlas header { display:grid; gap:7px; margin-bottom:16px; }\n.fos-atlas .standard { font-size:.76rem; letter-spacing:.13em; text-transform:uppercase; font-weight:650; color:var(--dawn); }\n.fos-atlas h2 { font-size:clamp(1.45rem,2.5vw,2.25rem); margin:0; color:var(--night); font-weight:620; line-height:1.08; }\n.fos-atlas .summary { margin:0; max-width:80ch; color:var(--slate); font-size:1rem; }\n.fos-atlas .toolbar { display:flex; flex-wrap:wrap; gap:8px; align-items:center; margin:10px 0 14px; }\n.fos-atlas .toolbar button {\n  font:inherit; color:var(--night); background:rgba(255,255,255,.78); border:1px solid rgba(78,97,120,.34);\n  border-radius:999px; min-height:38px; padding:7px 13px; cursor:pointer;\n}\n.fos-atlas .toolbar button:hover, .fos-atlas .toolbar button:focus-visible, .fos-atlas .toolbar button[aria-pressed=\'true\'] {\n  outline:3px solid rgba(229,195,122,.6); outline-offset:2px; background:#fff8e8;\n}\n.fos-atlas .stage {\n  background:rgba(255,255,255,.58); border:1px solid rgba(78,97,120,.26); border-radius:18px;\n  padding:12px; overflow:auto; backdrop-filter:blur(14px) saturate(125%);\n}\n.fos-atlas svg { width:100%; height:auto; min-width:760px; display:block; }\n.fos-atlas svg text { font-family:\'Jost\',Arial,sans-serif; fill:var(--ink); }\n.fos-atlas .node-shape { fill:rgba(255,255,255,.90); stroke:var(--slate); stroke-width:1.6; }\n.fos-atlas .node.person .node-shape { fill:#fff8e8; }\n.fos-atlas .node.system .node-shape { fill:#eaf6fb; stroke:var(--dawn); stroke-width:2.4; }\n.fos-atlas .node.external .node-shape { fill:#f5f3fb; }\n.fos-atlas .node.store .node-shape { fill:#eef8f4; }\n.fos-atlas .node.process .node-shape { fill:#eef6fb; }\n.fos-atlas .node.component .node-shape { fill:#f7fbfd; }\n.fos-atlas .node.state .node-shape { fill:#fffdf8; }\n.fos-atlas .node.entity .node-shape { fill:#fff; }\n.fos-atlas .node .node-title { font-size:15px; font-weight:650; }\n.fos-atlas .node .node-subtitle { font-size:11.5px; fill:var(--slate); }\n.fos-atlas .node-link { cursor:pointer; }\n.fos-atlas .node-link:hover .node-shape, .fos-atlas .node-link:focus .node-shape,\n.fos-atlas .node-link:focus-visible .node-shape { stroke:var(--gold); stroke-width:3; filter:drop-shadow(0 6px 8px rgba(11,21,48,.14)); }\n.fos-atlas .edge { fill:none; stroke:var(--slate); stroke-width:1.65; marker-end:url(#arrow); }\n.fos-atlas .edge.dashed { stroke-dasharray:7 6; }\n.fos-atlas .edge-label { font-size:11.5px; fill:var(--slate); paint-order:stroke; stroke:rgba(255,255,255,.96); stroke-width:5px; }\n.fos-atlas .dim { opacity:.13 !important; }\n.fos-atlas .hidden-by-filter { display:none !important; }\n.fos-atlas details { margin-top:15px; border-top:1px solid rgba(78,97,120,.25); padding-top:12px; }\n.fos-atlas summary { cursor:pointer; font-weight:620; color:var(--navy); min-height:34px; }\n.fos-atlas details p, .fos-atlas details li { line-height:1.48; }\n.fos-atlas .anchors { display:grid; grid-template-columns:repeat(auto-fit,minmax(220px,1fr)); gap:8px; padding:0; list-style:none; }\n.fos-atlas .anchors a { display:block; border:1px solid rgba(78,97,120,.22); border-radius:12px; padding:9px 11px; color:var(--navy); background:rgba(255,255,255,.7); text-decoration:none; }\n.fos-atlas .anchors a:hover, .fos-atlas .anchors a:focus-visible { text-decoration:underline; outline:3px solid rgba(102,168,201,.38); outline-offset:2px; }\n.fos-atlas .sr-only { position:absolute!important; width:1px!important; height:1px!important; padding:0!important; margin:-1px!important; overflow:hidden!important; clip:rect(0,0,0,0)!important; white-space:nowrap!important; border:0!important; }\n.fos-atlas .legend { display:flex; flex-wrap:wrap; gap:12px 18px; margin-top:10px; font-size:.84rem; color:var(--slate); }\n.fos-atlas .legend span::before { content:\'\'; display:inline-block; width:16px; height:11px; margin-right:6px; border:1.5px solid var(--slate); vertical-align:-1px; background:#fff; }\n.fos-atlas .legend .person::before { background:#fff8e8; border-radius:8px; }\n.fos-atlas .legend .system::before { background:#eaf6fb; border-width:2px; }\n.fos-atlas .legend .external::before { background:#f5f3fb; }\n.fos-atlas .legend .store::before { background:#eef8f4; border-radius:50%; }\n.fos-atlas table { width:100%; border-collapse:separate; border-spacing:0; background:rgba(255,255,255,.74); border:1px solid rgba(78,97,120,.28); border-radius:14px; overflow:hidden; }\n.fos-atlas caption { text-align:left; font-weight:620; padding:12px; color:var(--night); }\n.fos-atlas th, .fos-atlas td { padding:10px 9px; border-right:1px solid rgba(78,97,120,.17); border-bottom:1px solid rgba(78,97,120,.17); text-align:center; }\n.fos-atlas th { background:rgba(204,234,242,.54); color:var(--night); }\n.fos-atlas th[scope=\'row\'] { text-align:left; min-width:205px; }\n.fos-atlas td.yes { background:rgba(111,186,188,.18); font-weight:700; }\n.fos-atlas td.no { color:var(--slate); }\n.fos-atlas tr:last-child th, .fos-atlas tr:last-child td { border-bottom:0; }\n.fos-atlas th:last-child, .fos-atlas td:last-child { border-right:0; }\n.fos-atlas .source-note { font-size:.86rem; color:var(--slate); margin-top:10px; }\n@media (prefers-reduced-motion:reduce) { .fos-atlas * { scroll-behavior:auto!important; transition:none!important; } }\n@media (forced-colors:active) { .fos-atlas, .fos-atlas .stage, .fos-atlas .node-shape { background:Canvas; fill:Canvas; color:CanvasText; stroke:CanvasText; border-color:CanvasText; } }\n</style><section aria-describedby="fos-code-map-summary" aria-labelledby="fos-code-map-title" class="fos-atlas" id="fos-code-map" role="region">\n<header><h2 id="fos-code-map-title">How the codebase is organized</h2><p class="summary" id="fos-code-map-summary">From mission grammar to accepted scenario feeds planning; planning feeds command; command and environment feed visualization; orchestration connects persistence and verification.</p></header>\n<div aria-label="Subsystem filters" class="toolbar" role="toolbar"><button aria-controls="fos-code-map-stage" aria-pressed="true" data-filter="all" type="button">Show all</button><button aria-controls="fos-code-map-stage" aria-pressed="false" data-filter="scenario" type="button">Scenario</button><button aria-controls="fos-code-map-stage" aria-pressed="false" data-filter="force" type="button">Force</button><button aria-controls="fos-code-map-stage" aria-pressed="false" data-filter="command" type="button">Command</button><button aria-controls="fos-code-map-stage" aria-pressed="false" data-filter="visual" type="button">Visualization</button><button aria-controls="fos-code-map-stage" aria-pressed="false" data-filter="persistence" type="button">Persistence</button><button aria-controls="fos-code-map-stage" aria-pressed="false" data-filter="interface" type="button">Orchestration</button><button aria-controls="fos-code-map-stage" aria-pressed="false" data-filter="evidence" type="button">Evidence</button><span aria-live="polite" class="sr-only" data-live="">All system elements shown.</span></div>\n<div class="stage" id="fos-code-map-stage"><svg aria-labelledby="packages-svg-title packages-svg-desc" focusable="false" role="img" viewbox="0 0 1140 500">\n<title id="packages-svg-title">FOG OF SEA codebase organization</title>\n<desc id="packages-svg-desc">The codebase groups scenario, force planning, command, visualization, persistence, orchestration, and verification files around the game lifecycle.</desc>\n<defs>\n<marker id="arrow" markerheight="10" markerunits="strokeWidth" markerwidth="10" orient="auto" refx="9" refy="3"><path d="M0,0 L0,6 L9,3 z" fill="#4e6178"></path></marker>\n</defs><a aria-label="Scenario modules. gameModel.ts scenarioMatrix.ts operationalStrategy.ts Scenario modules gameModel.ts scenarioMatrix.ts operationalStrategy.ts. Open app/gameModel.ts, lines 1 through 140." class="node-link node" data-node="pkg-scenario" data-tags="scenario" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/gameModel.ts, lines 1 through 140"><title>Scenario modules. gameModel.ts\nscenarioMatrix.ts\noperationalStrategy.ts</title><g class="node external"><rect class="node-shape" height="130" rx="16" width="230" x="35" y="60"></rect><text class="node-title" text-anchor="middle"><tspan x="150.0" y="117.0">Scenario modules</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="150.0" y="128.0">gameModel.ts</tspan><tspan x="150.0" y="145.0">scenarioMatrix.ts</tspan><tspan x="150.0" y="162.0">operationalStrategy.ts</tspan></text></g></a><a aria-label="Force-planning modules. catalog.ts planningAssessment.ts forceReadiness.ts Force-planning modules catalog.ts planningAssessment.ts forceReadiness.ts. Open app/forceReadiness.ts, lines 1 through 320." class="node-link node" data-node="pkg-force" data-tags="force" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" role="link" tabindex="0" target="_blank" title="app/forceReadiness.ts, lines 1 through 320"><title>Force-planning modules. catalog.ts\nplanningAssessment.ts\nforceReadiness.ts</title><g class="node external"><rect class="node-shape" height="130" rx="16" width="230" x="315" y="60"></rect><text class="node-title" text-anchor="middle"><tspan x="430.0" y="117.0">Force-planning modules</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="430.0" y="128.0">catalog.ts</tspan><tspan x="430.0" y="145.0">planningAssessment.ts</tspan><tspan x="430.0" y="162.0">forceReadiness.ts</tspan></text></g></a><a aria-label="Command modules. commandPhase.ts kriegsspiel.ts riskStrategy.ts Command modules commandPhase.ts kriegsspiel.ts riskStrategy.ts. Open app/commandPhase.ts, lines 1 through 280." class="node-link node" data-node="pkg-command" data-tags="command" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" role="link" tabindex="0" target="_blank" title="app/commandPhase.ts, lines 1 through 280"><title>Command modules. commandPhase.ts\nkriegsspiel.ts\nriskStrategy.ts</title><g class="node external"><rect class="node-shape" height="130" rx="16" width="230" x="595" y="60"></rect><text class="node-title" text-anchor="middle"><tspan x="710.0" y="117.0">Command modules</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="710.0" y="128.0">commandPhase.ts</tspan><tspan x="710.0" y="145.0">kriegsspiel.ts</tspan><tspan x="710.0" y="162.0">riskStrategy.ts</tspan></text></g></a><a aria-label="Visualization modules. Battlefield.tsx battlefieldScene.ts environmentVisuals.ts Visualization modules Battlefield.tsx battlefieldScene.ts environmentVisuals.ts. Open app/battlefieldScene.ts, lines 1 through 260." class="node-link node" data-node="pkg-visual" data-tags="visual" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/battlefieldScene.ts#L1-L260" rel="noopener" role="link" tabindex="0" target="_blank" title="app/battlefieldScene.ts, lines 1 through 260"><title>Visualization modules. Battlefield.tsx\nbattlefieldScene.ts\nenvironmentVisuals.ts</title><g class="node external"><rect class="node-shape" height="130" rx="16" width="230" x="875" y="60"></rect><text class="node-title" text-anchor="middle"><tspan x="990.0" y="117.0">Visualization modules</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="990.0" y="128.0">Battlefield.tsx</tspan><tspan x="990.0" y="145.0">battlefieldScene.ts</tspan><tspan x="990.0" y="162.0">environmentVisuals.ts</tspan></text></g></a><a aria-label="Persistence modules. saveGame.ts browserSaves.ts inputSecurity.ts Persistence modules saveGame.ts browserSaves.ts inputSecurity.ts. Open app/saveGame.ts, lines 1 through 180." class="node-link node" data-node="pkg-persistence" data-tags="persistence" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/saveGame.ts#L1-L180" rel="noopener" role="link" tabindex="0" target="_blank" title="app/saveGame.ts, lines 1 through 180"><title>Persistence modules. saveGame.ts\nbrowserSaves.ts\ninputSecurity.ts</title><g class="node external"><rect class="node-shape" height="130" rx="16" width="230" x="175" y="300"></rect><text class="node-title" text-anchor="middle"><tspan x="290.0" y="357.0">Persistence modules</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="290.0" y="368.0">saveGame.ts</tspan><tspan x="290.0" y="385.0">browserSaves.ts</tspan><tspan x="290.0" y="402.0">inputSecurity.ts</tspan></text></g></a><a aria-label="Orchestration modules. page.tsx useGameSession.ts UI components Orchestration modules page.tsx useGameSession.ts UI components. Open app/page.tsx, lines 1 through 140." class="node-link node" data-node="pkg-ui" data-tags="interface" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" role="link" tabindex="0" target="_blank" title="app/page.tsx, lines 1 through 140"><title>Orchestration modules. page.tsx\nuseGameSession.ts\nUI components</title><g class="node external"><rect class="node-shape" height="130" rx="16" width="230" x="455" y="300"></rect><text class="node-title" text-anchor="middle"><tspan x="570.0" y="357.0">Orchestration modules</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="570.0" y="368.0">page.tsx</tspan><tspan x="570.0" y="385.0">useGameSession.ts</tspan><tspan x="570.0" y="402.0">UI components</tspan></text></g></a><a aria-label="Test and policy files. tests/*.test.ts ACCESSIBILITY.md SECURITY.md Test and policy files tests/*.test.ts ACCESSIBILITY.md SECURITY.md. Open tests/scenario-variety.test.ts, lines 1 through 180." class="node-link node" data-node="pkg-tests" data-tags="evidence" href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/scenario-variety.test.ts#L1-L180" rel="noopener" role="link" tabindex="0" target="_blank" title="tests/scenario-variety.test.ts, lines 1 through 180"><title>Test and policy files. tests/*.test.ts\nACCESSIBILITY.md\nSECURITY.md</title><g class="node external"><rect class="node-shape" height="130" rx="16" width="230" x="735" y="300"></rect><text class="node-title" text-anchor="middle"><tspan x="850.0" y="357.0">Test and policy files</tspan></text><text class="node-subtitle" text-anchor="middle"><tspan x="850.0" y="368.0">tests/*.test.ts</tspan><tspan x="850.0" y="385.0">ACCESSIBILITY.md</tspan><tspan x="850.0" y="402.0">SECURITY.md</tspan></text></g></a><g data-edge="" data-tags="scenario force"><path class="edge" d="M265 125 L315 125"></path><text class="edge-label" text-anchor="middle" x="290.0" y="118.0">scenario types</text></g><g data-edge="" data-tags="force command"><path class="edge" d="M545 125 L595 125"></path><text class="edge-label" text-anchor="middle" x="570.0" y="118.0">rigid readiness</text></g><g data-edge="" data-tags="command visual"><path class="edge" d="M825 125 L875 125"></path><text class="edge-label" text-anchor="middle" x="850.0" y="118.0">state + environment</text></g><g data-edge="" data-tags="persistence command"><path class="edge" d="M290 300 V245 H570 V190"></path><text class="edge-label" text-anchor="middle" x="435" y="235">save / restore</text></g><g data-edge="" data-tags="interface persistence"><path class="edge" d="M455 365 H405"></path><text class="edge-label" text-anchor="middle" x="430" y="352">dispatch + persistence</text></g><g data-edge="" data-tags="interface force scenario"><path class="edge" d="M570 300 V235 H430 V190"></path><text class="edge-label" text-anchor="middle" x="500" y="225">coordinates</text></g><g data-edge="" data-tags="interface evidence"><path class="edge" d="M685 365 H735"></path><text class="edge-label" text-anchor="middle" x="710" y="352">verified by</text></g><g data-edge="" data-tags="visual evidence"><path class="edge" d="M825 190 V245 H850 V300"></path><text class="edge-label" text-anchor="middle" x="840" y="236">verified by</text></g></svg></div>\n<div aria-label="Legend" class="legend"><span class="external">Repository group</span><span class="system">Dependency</span></div>\n<div class="implementation-references" style="margin:16px 0 8px;padding:12px 14px;border-radius:14px;background:rgba(255,255,255,.72);border:1px solid rgba(78,97,120,.24);font-family:Jost,Arial,sans-serif;"><strong>Source</strong><ul style="margin:8px 0 0 1.2rem;padding:0;display:grid;gap:4px;"><li><code>app/gameModel.ts</code>, lines <a aria-label="Open app/gameModel.ts, lines 1 through 140." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/gameModel.ts#L1-L140" rel="noopener" target="_blank" title="app/gameModel.ts, lines 1 through 140">1–140</a></li><li><code>app/forceReadiness.ts</code>, lines <a aria-label="Open app/forceReadiness.ts, lines 1 through 320." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/forceReadiness.ts#L1-L320" rel="noopener" target="_blank" title="app/forceReadiness.ts, lines 1 through 320">1–320</a></li><li><code>app/commandPhase.ts</code>, lines <a aria-label="Open app/commandPhase.ts, lines 1 through 280." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/commandPhase.ts#L1-L280" rel="noopener" target="_blank" title="app/commandPhase.ts, lines 1 through 280">1–280</a></li><li><code>app/battlefieldScene.ts</code>, lines <a aria-label="Open app/battlefieldScene.ts, lines 1 through 260." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/battlefieldScene.ts#L1-L260" rel="noopener" target="_blank" title="app/battlefieldScene.ts, lines 1 through 260">1–260</a></li><li><code>app/saveGame.ts</code>, lines <a aria-label="Open app/saveGame.ts, lines 1 through 180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/saveGame.ts#L1-L180" rel="noopener" target="_blank" title="app/saveGame.ts, lines 1 through 180">1–180</a></li><li><code>app/page.tsx</code>, lines <a aria-label="Open app/page.tsx, lines 1 through 140." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/app/page.tsx#L1-L140" rel="noopener" target="_blank" title="app/page.tsx, lines 1 through 140">1–140</a></li><li><code>tests/scenario-variety.test.ts</code>, lines <a aria-label="Open tests/scenario-variety.test.ts, lines 1 through 180." href="https://github.com/howardhayden/fogofsea/blob/d77bdd63189908d9090c1578e20d6f5ce05814c4/tests/scenario-variety.test.ts#L1-L180" rel="noopener" target="_blank" title="tests/scenario-variety.test.ts, lines 1 through 180">1–180</a></li></ul></div><details><summary>Description</summary><p>Scenario modules define accepted problems and matrices. Force-planning modules define catalogs, hosting, credit, adaptation, and readiness. Command modules resolve rigid turns and risk effects. Visualization modules render the accepted environment and disclosed state. Persistence modules validate browser and portable data. Orchestration modules coordinate UI phases and typed session actions. Tests and trust documents provide evidence.</p></details>\n<script>(function(){\n const root=document.getElementById(\'fos-code-map\'); if(!root) return;\n const buttons=[...root.querySelectorAll(\'[data-filter]\')];\n const tagged=[...root.querySelectorAll(\'[data-tags]\')];\n const live=root.querySelector(\'[data-live]\');\n function setFilter(tag,label){\n   tagged.forEach(el=>{ const tags=(el.getAttribute(\'data-tags\')||\'\').split(/\\s+/); el.classList.toggle(\'dim\', tag!==\'all\' && !tags.includes(tag)); });\n   buttons.forEach(b=>b.setAttribute(\'aria-pressed\',String(b.dataset.filter===tag)));\n   if(live) live.textContent=tag===\'all\'?\'All system elements shown.\':label+\' relationships emphasized.\';\n }\n buttons.forEach(b=>b.addEventListener(\'click\',()=>setFilter(b.dataset.filter,b.textContent.trim())));\n})();</script></section>'))
# Out:
# <style>
# @font-face {
#   font-family: 'Jost';
#   src: url('https://raw.githubusercontent.com/howardhayden/fogofsea/d77bdd63189908d9090c1578e20d6f5ce05814c4/node_modules/%40fontsource-variable/jost/files/jost-latin-wght-normal.woff2') format('woff2');
#   font-weight: 100 900;
#   font-style: normal;
#   font-display: swap;
# }
# .fos-atlas {
#   --night:#0b1530; --navy:#132347; --dawn:#335c89;
#   --sea:#66a8c9; --foam:#cceaf2; --glass:#edf8fb;
#   --gold:#e5c37a; --mist:#9fb8c9; --slate:#4e6178;
#   --ink:#102033; --coral:#d9897a; --teal:#6fbabc;
#   font-family:'Jost',Arial,sans-serif; color:var(--ink);
#   background:
#     radial-gradient(circle at 12% 0%, rgba(204,234,242,.84), transparent 34%),
#     radial-gradient(circle at 92% 8%, rgba(243,215,162,.46), transparent 27%),
#     linear-gradient(145deg, rgba(237,248,251,.96), rgba(255,255,255,.84));
#   border:1px solid rgba(78,97,120,.34); border-radius:22px;
# ...
